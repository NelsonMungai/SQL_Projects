# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/Logo blue_dark.png"  style="width:25px" align="right";/>
# </div>

# %% [markdown]
# # Top-N analysis using ranking window functions
# © ExploreAI Academy

# %% [markdown]
# In this notebook, we explore the use of ranking functions to order the elements in our database table based on a certain criterion.

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# In this train, we will learn:
# - How to use the `ROW_NUMBER()` and `RANK()` functions to perform partition-wise ranking operations.
# - How the ranking results of these two functions differ from each other.

# %% [markdown]
# ## Overview
#
# Let's say we want to quickly order the countries from worst to best in terms of levels of access to drinking water services per year.
#
# We can use Top-N analysis which focuses on identifying and analysing the highest-ranked elements in a dataset based on a specific criterion. The criterion in our case is ‘levels of access to managed drinking water services per year.’
#
# **SQL ranking functions** will be useful in this case.

# %% [markdown]
# ## Connecting to our MySQL database
#
# We will use our `Access_to_Basic_Services` table in our `united_nations` database that we created in MySQL Workbench. We can apply the same queries we used in MySQL Workbench in this notebook if we connect to our MySQL server by running the cells below.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://cybergod:example-password@localhost:3306/united_nations

# %% [markdown]
# ## Exercise

# %% [markdown]
# Let's enter the following base query which selects the three columns we will be using from our `Access_to_Basic_Services` table: `Country_name`, `Time_period`, and `Pct_managed_drinking_water_services`.

# %%
# %%sql
#
# SELECT
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services
# FROM
#     united_nations.Access_to_basic_services;
# Out:
#  * mysql+pymysql://cybergod:***@localhost:3306/united_nations
# 1048 rows affected.
# [('Kazakhstan', 2015, 94.67),
#  ('Kazakhstan', 2016, 94.67),
#  ('Kazakhstan', 2017, 95.0),
#  ('Kazakhstan', 2018, 95.0),
#  ('Kazakhstan', 2019, 95.0),
#  ('Kazakhstan', 2020, 95.0),
#  ('Kyrgyzstan', 2015, 89.67),
#  ('Kyrgyzstan', 2016, 90.33),
#  ('Kyrgyzstan', 2017, 91.0),
#  ('Kyrgyzstan', 2018, 91.33),
#  ('Kyrgyzstan', 2019, 91.67),
#  ('Kyrgyzstan', 2020, 92.67),
#  ('Tajikistan', 2015, 80.33),
#  ('Tajikistan', 2016, 81.33),
#  ('Tajikistan', 2017, 82.33),
#  ('Tajikistan', 2018, 83.33),
#  ('Tajikistan', 2019, 85.0),
#  ('Tajikistan', 2020, 85.0),
#  ('Turkmenistan', 2015, 97.67),
#  ('Turkmenistan', 2016, 98.0),
#  ('Turkmenistan', 2017, 98.67),
#  ('Turkmenistan', 2018, 99.33),
#  ('Turkmenistan', 2019, 100.0),
#  ('Turkmenistan', 2020, 100.0),
#  ('Uzbekistan', 2015, 97.67),
#  ('Uzbekistan', 2016, 97.67),
#  ('Uzbekistan', 2017, 98.0),
#  ('Uzbekistan', 2018, 98.0),
#  ('Uzbekistan', 2019, 98.0),
#  ('Uzbekistan', 2020, 98.0),
#  ('Afghanistan', 2015, 67.0),
#  ('Afghanistan', 2016, 69.67),
#  ('Afghanistan', 2017, 72.33),
#  ('Afghanistan', 2018, 75.33),
#  ('Afghanistan', 2019, 78.0),
#  ('Afghanistan', 2020, 80.33),
#  ('Bangladesh', 2015, 97.33),
#  ('Bangladesh', 2016, 97.33),
#  ('Bangladesh', 2017, 97.33),
#  ('Bangladesh', 2018, 97.33),
#  ('Bangladesh', 2019, 97.67),
#  ('Bangladesh', 2020, 97.67),
#  ('Bhutan', 2015, 96.33),
#  ('Bhutan', 2016, 97.0),
#  ('Bhutan', 2017, 97.33),
#  ('Bhutan', 2018, 97.33),
#  ('Bhutan', 2019, 97.33),
#  ('Bhutan', 2020, 97.33),
#  ('India', 2015, 89.0),
#  ('India', 2016, 89.33),
#  ('India', 2017, 90.0),
#  ('India', 2018, 90.33),
#  ('India', 2019, 90.67),
#  ('India', 2020, 91.0),
#  ('Iran (Islamic Republic of)', 2015, 95.67),
#  ('Iran (Islamic Republic of)', 2016, 96.0),
#  ('Iran (Islamic Republic of)', 2017, 96.33),
#  ('Iran (Islamic Republic of)', 2018, 96.33),
#  ('Iran (Islamic Republic of)', 2019, 96.33),
#  ('Iran (Islamic Republic of)', 2020, 96.67),
#  ('Maldives', 2015, 99.0),
#  ('Maldives', 2016, 99.0),
#  ('Maldives', 2017, 99.33),
#  ('Maldives', 2018, 99.33),
#  ('Maldives', 2019, 99.67),
#  ('Maldives', 2020, 99.67),
#  ('Nepal', 2015, 88.33),
#  ('Nepal', 2016, 88.67),
#  ('Nepal', 2017, 89.0),
#  ('Nepal', 2018, 89.33),
#  ('Nepal', 2019, 90.0),
#  ('Nepal', 2020, 90.0),
#  ('Pakistan', 2015, 90.0),
#  ('Pakistan', 2016, 90.0),
#  ('Pakistan', 2017, 90.33),
#  ('Pakistan', 2018, 90.33),
#  ('Pakistan', 2019, 90.33),
#  ('Pakistan', 2020, 90.67),
#  ('Sri Lanka', 2015, 92.0),
#  ('Sri Lanka', 2016, 93.0),
#  ('Sri Lanka', 2017, 93.67),
#  ('Sri Lanka', 2018, 94.33),
#  ('Sri Lanka', 2019, 94.33),
#  ('Sri Lanka', 2020, 94.33),
#  ('China', 2015, 91.33),
#  ('China', 2016, 91.33),
#  ('China', 2017, 92.0),
#  ('China', 2018, 92.67),
#  ('China', 2019, 93.33),
#  ('China', 2020, 93.67),
#  ("Democratic People's Republic of Korea", 2015, 94.67),
#  ("Democratic People's Republic of Korea", 2016, 94.33),
#  ("Democratic People's Republic of Korea", 2017, 94.0),
#  ("Democratic People's Republic of Korea", 2018, 93.33),
#  ("Democratic People's Republic of Korea", 2019, 93.33),
#  ("Democratic People's Republic of Korea", 2020, 93.33),
#  ('Japan', 2015, 99.0),
#  ('Japan', 2016, 99.0),
#  ('Japan', 2017, 99.0),
#  ('Japan', 2018, 99.0),
#  ('Japan', 2019, 99.0),
#  ('Japan', 2020, 99.0),
#  ('Mongolia', 2015, 75.67),
#  ('Mongolia', 2016, 77.0),
#  ('Mongolia', 2017, 78.0),
#  ('Mongolia', 2018, 79.0),
#  ('Mongolia', 2019, 80.0),
#  ('Mongolia', 2020, 81.0),
#  ('Republic of Korea', 2015, 99.0),
#  ('Republic of Korea', 2016, 100.0),
#  ('Republic of Korea', 2017, 100.0),
#  ('Republic of Korea', 2018, 100.0),
#  ('Republic of Korea', 2019, 100.0),
#  ('Republic of Korea', 2020, 100.0),
#  ('Brunei Darussalam', 2015, 99.67),
#  ('Brunei Darussalam', 2016, 100.0),
#  ('Brunei Darussalam', 2017, 100.0),
#  ('Brunei Darussalam', 2018, 100.0),
#  ('Brunei Darussalam', 2019, 100.0),
#  ('Brunei Darussalam', 2020, 100.0),
#  ('Cambodia', 2015, 73.33),
#  ('Cambodia', 2016, 73.67),
#  ('Cambodia', 2017, 74.33),
#  ('Cambodia', 2018, 74.67),
#  ('Cambodia', 2019, 75.33),
#  ('Cambodia', 2020, 75.33),
#  ('Indonesia', 2015, 88.33),
#  ('Indonesia', 2016, 89.0),
#  ('Indonesia', 2017, 89.67),
#  ('Indonesia', 2018, 90.67),
#  ('Indonesia', 2019, 91.33),
#  ('Indonesia', 2020, 92.0),
#  ("Lao People's Democratic Republic", 2015, 79.67),
#  ("Lao People's Democratic Republic", 2016, 82.0),
#  ("Lao People's Democratic Republic", 2017, 83.33),
#  ("Lao People's Democratic Republic", 2018, 85.0),
#  ("Lao People's Democratic Republic", 2019, 86.67),
#  ("Lao People's Democratic Republic", 2020, 86.67),
#  ('Malaysia', 2015, 95.67),
#  ('Malaysia', 2016, 95.67),
#  ('Malaysia', 2017, 95.67),
#  ('Malaysia', 2018, 95.33),
#  ('Malaysia', 2019, 95.33),
#  ('Malaysia', 2020, 95.33),
#  ('Myanmar', 2015, 76.33),
#  ('Myanmar', 2016, 78.33),
#  ('Myanmar', 2017, 80.33),
#  ('Myanmar', 2018, 82.33),
#  ('Myanmar', 2019, 84.0),
#  ('Myanmar', 2020, 85.67),
#  ('Philippines', 2015, 92.0),
#  ('Philippines', 2016, 92.67),
#  ('Philippines', 2017, 93.0),
#  ('Philippines', 2018, 93.33),
#  ('Philippines', 2019, 93.67),
#  ('Philippines', 2020, 94.0),
#  ('Singapore', 2015, 100.0),
#  ('Singapore', 2016, 100.0),
#  ('Singapore', 2017, 100.0),
#  ('Singapore', 2018, 100.0),
#  ('Singapore', 2019, 100.0),
#  ('Singapore', 2020, 100.0),
#  ('Thailand', 2015, 99.33),
#  ('Thailand', 2016, 99.33),
#  ('Thailand', 2017, 100.0),
#  ('Thailand', 2018, 100.0),
#  ('Thailand', 2019, 100.0),
#  ('Thailand', 2020, 100.0),
#  ('Timor-Leste', 2015, 78.0),
#  ('Timor-Leste', 2016, 80.67),
#  ('Timor-Leste', 2017, 82.33),
#  ('Timor-Leste', 2018, 84.33),
#  ('Timor-Leste', 2019, 86.0),
#  ('Timor-Leste', 2020, 87.0),
#  ('Viet Nam', 2015, 94.0),
#  ('Viet Nam', 2016, 95.0),
#  ('Viet Nam', 2017, 95.67),
#  ('Viet Nam', 2018, 96.33),
#  ('Viet Nam', 2019, 96.67),
#  ('Viet Nam', 2020, 97.33),
#  ('Bermuda', 2015, 100.0),
#  ('Bermuda', 2016, 100.0),
#  ('Bermuda', 2017, 100.0),
#  ('Bermuda', 2018, 100.0),
#  ('Bermuda', 2019, 100.0),
#  ('Bermuda', 2020, 100.0),
#  ('Canada', 2015, 99.0),
#  ('Canada', 2016, 99.0),
#  ('Canada', 2017, 99.0),
#  ('Canada', 2018, 99.0),
#  ('Canada', 2019, 99.0),
#  ('Canada', 2020, 99.0),
#  ('Greenland', 2015, 100.0),
#  ('Greenland', 2016, 100.0),
#  ('Greenland', 2017, 100.0),
#  ('Greenland', 2018, 100.0),
#  ('Greenland', 2019, 100.0),
#  ('Greenland', 2020, 100.0),
#  ('Saint Pierre and Miquelon', 2015, 91.0),
#  ('Saint Pierre and Miquelon', 2016, 91.0),
#  ('Saint Pierre and Miquelon', 2017, 91.0),
#  ('Saint Pierre and Miquelon', 2018, 91.0),
#  ('Saint Pierre and Miquelon', 2019, 91.0),
#  ('Saint Pierre and Miquelon', 2020, 91.0),
#  ('United States of America', 2015, 99.0),
#  ('United States of America', 2016, 99.33),
#  ('United States of America', 2017, 99.67),
#  ('United States of America', 2018, 99.67),
#  ('United States of America', 2019, 99.67),
#  ('United States of America', 2020, 100.0),
#  ('Anguilla', 2015, 97.0),
#  ('Anguilla', 2016, 97.0),
#  ('Anguilla', 2017, 97.0),
#  ('Antigua and Barbuda', 2015, 97.0),
#  ('Antigua and Barbuda', 2016, 97.0),
#  ('Antigua and Barbuda', 2017, 97.0),
#  ('Aruba', 2015, 98.0),
#  ('Aruba', 2016, 98.0),
#  ('Bahamas', 2015, 99.0),
#  ('Bahamas', 2016, 99.0),
#  ('Bahamas', 2017, 99.0),
#  ('Bahamas', 2018, 99.0),
#  ('Bahamas', 2019, 99.0),
#  ('Barbados', 2015, 98.0),
#  ('Barbados', 2016, 98.0),
#  ('Barbados', 2017, 98.0),
#  ('Barbados', 2018, 99.0),
#  ('Barbados', 2019, 99.0),
#  ('Barbados', 2020, 99.0),
#  ('British Virgin Islands', 2015, 100.0),
#  ('British Virgin Islands', 2016, 100.0),
#  ('British Virgin Islands', 2017, 100.0),
#  ('British Virgin Islands', 2018, 100.0),
#  ('British Virgin Islands', 2019, 100.0),
#  ('British Virgin Islands', 2020, 100.0),
#  ('Cayman Islands', 2015, 96.0),
#  ('Cayman Islands', 2016, 96.0),
#  ('Cuba', 2015, 94.67),
#  ('Cuba', 2016, 95.0),
#  ('Cuba', 2017, 95.33),
#  ('Cuba', 2018, 96.0),
#  ('Cuba', 2019, 96.33),
#  ('Cuba', 2020, 96.33),
#  ('Curaçao', 2015, 99.0),
#  ('Curaçao', 2016, 99.0),
#  ('Curaçao', 2017, 99.0),
#  ('Dominica', 2015, 95.0),
#  ('Dominica', 2016, 95.0),
#  ('Dominica', 2017, 95.0),
#  ('Dominican Republic', 2015, 94.33),
#  ('Dominican Republic', 2016, 94.67),
#  ('Dominican Republic', 2017, 94.67),
#  ('Dominican Republic', 2018, 95.0),
#  ('Dominican Republic', 2019, 95.0),
#  ('Dominican Republic', 2020, 95.0),
#  ('Grenada', 2015, 96.0),
#  ('Grenada', 2016, 96.0),
#  ('Grenada', 2017, 96.0),
#  ('Guadeloupe', 2015, 100.0),
#  ('Guadeloupe', 2016, 100.0),
#  ('Guadeloupe', 2017, 100.0),
#  ('Guadeloupe', 2018, 100.0),
#  ('Guadeloupe', 2019, 100.0),
#  ('Guadeloupe', 2020, 100.0),
#  ('Haiti', 2015, 64.0),
#  ('Haiti', 2016, 64.33),
#  ('Haiti', 2017, 64.33),
#  ('Haiti', 2018, 64.67),
#  ('Haiti', 2019, 64.67),
#  ('Haiti', 2020, 65.0),
#  ('Jamaica', 2015, 90.0),
#  ('Jamaica', 2016, 90.33),
#  ('Jamaica', 2017, 90.33),
#  ('Jamaica', 2018, 90.33),
#  ('Jamaica', 2019, 90.33),
#  ('Jamaica', 2020, 90.33),
#  ('Martinique', 2015, 100.0),
#  ('Martinique', 2016, 100.0),
#  ('Martinique', 2017, 100.0),
#  ('Martinique', 2018, 100.0),
#  ('Martinique', 2019, 100.0),
#  ('Martinique', 2020, 100.0),
#  ('Montserrat', 2015, 98.0),
#  ('Montserrat', 2016, 98.0),
#  ('Montserrat', 2017, 98.0),
#  ('Montserrat', 2018, 98.0),
#  ('Montserrat', 2019, 98.0),
#  ('Montserrat', 2020, 98.0),
#  ('Puerto Rico', 2015, 99.0),
#  ('Puerto Rico', 2016, 100.0),
#  ('Puerto Rico', 2017, 100.0),
#  ('Puerto Rico', 2018, 100.0),
#  ('Puerto Rico', 2019, 100.0),
#  ('Puerto Rico', 2020, 100.0),
#  ('Saint Barthélemy', 2015, 100.0),
#  ('Saint Barthélemy', 2016, 100.0),
#  ('Saint Barthélemy', 2017, 100.0),
#  ('Saint Barthélemy', 2018, 100.0),
#  ('Saint Barthélemy', 2019, 100.0),
#  ('Saint Barthélemy', 2020, 100.0),
#  ('Saint Kitts and Nevis', 2015, 99.0),
#  ('Saint Kitts and Nevis', 2016, 99.0),
#  ('Saint Kitts and Nevis', 2017, 99.0),
#  ('Saint Lucia', 2015, 96.0),
#  ('Saint Lucia', 2016, 96.33),
#  ('Saint Lucia', 2017, 96.33),
#  ('Saint Lucia', 2018, 97.0),
#  ('Saint Lucia', 2019, 97.0),
#  ('Saint Lucia', 2020, 97.0),
#  ('Saint Martin (French Part)', 2015, 100.0),
#  ('Saint Martin (French Part)', 2016, 100.0),
#  ('Saint Martin (French Part)', 2017, 100.0),
#  ('Saint Martin (French Part)', 2018, 100.0),
#  ('Saint Martin (French Part)', 2019, 100.0),
#  ('Saint Martin (French Part)', 2020, 100.0),
#  ('Saint Vincent and the Grenadines', 2015, 95.0),
#  ('Saint Vincent and the Grenadines', 2016, 95.0),
#  ('Saint Vincent and the Grenadines', 2017, 95.0),
#  ('Saint Vincent and the Grenadines', 2018, 95.0),
#  ('Sint Maarten (Dutch part)', 2015, 95.0),
#  ('Sint Maarten (Dutch part)', 2016, 95.0),
#  ('Sint Maarten (Dutch part)', 2017, 95.0),
#  ('Trinidad and Tobago', 2015, 98.0),
#  ('Trinidad and Tobago', 2016, 99.0),
#  ('Trinidad and Tobago', 2017, 99.0),
#  ('Trinidad and Tobago', 2018, 99.0),
#  ('Trinidad and Tobago', 2019, 99.0),
#  ('Trinidad and Tobago', 2020, 99.0),
#  ('Turks and Caicos Islands', 2015, 94.0),
#  ('Turks and Caicos Islands', 2016, 94.0),
#  ('Turks and Caicos Islands', 2017, 94.0),
#  ('Turks and Caicos Islands', 2018, 94.0),
#  ('United States Virgin Islands', 2015, 99.0),
#  ('United States Virgin Islands', 2016, 99.0),
#  ('United States Virgin Islands', 2017, 99.0),
#  ('United States Virgin Islands', 2018, 99.0),
#  ('United States Virgin Islands', 2019, 99.0),
#  ('United States Virgin Islands', 2020, 99.0),
#  ('Belize', 2015, 97.33),
#  ('Belize', 2016, 97.67),
#  ('Belize', 2017, 98.0),
#  ('Belize', 2018, 98.33),
#  ('Belize', 2019, 98.33),
#  ('Belize', 2020, 98.33),
#  ('Costa Rica', 2015, 99.0),
#  ('Costa Rica', 2016, 99.67),
#  ('Costa Rica', 2017, 100.0),
#  ('Costa Rica', 2018, 100.0),
#  ('Costa Rica', 2019, 100.0),
#  ('Costa Rica', 2020, 100.0),
#  ('El Salvador', 2015, 94.33),
#  ('El Salvador', 2016, 95.33),
#  ('El Salvador', 2017, 96.0),
#  ('El Salvador', 2018, 97.0),
#  ('El Salvador', 2019, 97.0),
#  ('El Salvador', 2020, 97.0),
#  ('Guatemala', 2015, 92.0),
#  ('Guatemala', 2016, 92.33),
#  ('Guatemala', 2017, 92.67),
#  ('Guatemala', 2018, 93.0),
#  ('Guatemala', 2019, 94.0),
#  ('Guatemala', 2020, 94.0),
#  ('Honduras', 2015, 92.67),
#  ('Honduras', 2016, 93.33),
#  ('Honduras', 2017, 93.67),
#  ('Honduras', 2018, 94.33),
#  ('Honduras', 2019, 94.67),
#  ('Honduras', 2020, 95.33),
#  ('Mexico', 2015, 96.67),
#  ('Mexico', 2016, 97.33),
#  ('Mexico', 2017, 98.0),
#  ('Mexico', 2018, 98.33),
#  ('Mexico', 2019, 98.67),
#  ('Mexico', 2020, 99.33),
#  ('Nicaragua', 2015, 79.33),
#  ('Nicaragua', 2016, 79.0),
#  ('Nicaragua', 2017, 79.0),
#  ('Nicaragua', 2018, 79.33),
#  ('Nicaragua', 2019, 79.33),
#  ('Nicaragua', 2020, 79.33),
#  ('Panama', 2015, 91.67),
#  ('Panama', 2016, 91.67),
#  ('Panama', 2017, 92.33),
#  ('Panama', 2018, 92.33),
#  ('Panama', 2019, 92.67),
#  ('Panama', 2020, 92.67),
#  ('Argentina', 2015, 97.33),
#  ('Argentina', 2016, 97.33),
#  ('Argentina', 2017, 100.0),
#  ('Argentina', 2018, 100.0),
#  ('Argentina', 2019, 100.0),
#  ('Argentina', 2020, 100.0),
#  ('Bolivia (Plurinational State of)', 2015, 87.33),
#  ('Bolivia (Plurinational State of)', 2016, 88.0),
#  ('Bolivia (Plurinational State of)', 2017, 89.0),
#  ('Bolivia (Plurinational State of)', 2018, 89.67),
#  ('Bolivia (Plurinational State of)', 2019, 90.33),
#  ('Bolivia (Plurinational State of)', 2020, 90.67),
#  ('Brazil', 2015, 95.33),
#  ('Brazil', 2016, 95.33),
#  ('Brazil', 2017, 96.33),
#  ('Brazil', 2018, 97.0),
#  ('Brazil', 2019, 97.33),
#  ('Brazil', 2020, 98.33),
#  ('Chile', 2015, 99.0),
#  ('Chile', 2016, 99.67),
#  ('Chile', 2017, 100.0),
#  ('Chile', 2018, 100.0),
#  ('Chile', 2019, 100.0),
#  ('Chile', 2020, 100.0),
#  ('Colombia', 2015, 93.0),
#  ('Colombia', 2016, 93.67),
#  ('Colombia', 2017, 94.0),
#  ('Colombia', 2018, 94.0),
#  ('Colombia', 2019, 94.33),
#  ('Colombia', 2020, 94.67),
#  ('Ecuador', 2015, 91.67),
#  ('Ecuador', 2016, 92.33),
#  ('Ecuador', 2017, 92.67),
#  ('Ecuador', 2018, 93.33),
#  ('Ecuador', 2019, 93.67),
#  ('Ecuador', 2020, 94.0),
#  ('Falkland Islands (Malvinas)', 2015, 91.0),
#  ('Falkland Islands (Malvinas)', 2016, 91.0),
#  ('Falkland Islands (Malvinas)', 2017, 91.0),
#  ('Falkland Islands (Malvinas)', 2018, 91.0),
#  ('Falkland Islands (Malvinas)', 2019, 91.0),
#  ('Falkland Islands (Malvinas)', 2020, 91.0),
#  ('French Guiana', 2015, 94.0),
#  ('French Guiana', 2016, 94.0),
#  ('French Guiana', 2017, 94.0),
#  ('French Guiana', 2018, 94.0),
#  ('French Guiana', 2019, 94.0),
#  ('French Guiana', 2020, 94.0),
#  ('Guyana', 2015, 96.0),
#  ('Guyana', 2016, 96.67),
#  ('Guyana', 2017, 96.67),
#  ('Guyana', 2018, 96.67),
#  ('Guyana', 2019, 96.67),
#  ('Guyana', 2020, 96.67),
#  ('Paraguay', 2015, 96.33),
#  ('Paraguay', 2016, 97.67),
#  ('Paraguay', 2017, 99.33),
#  ('Paraguay', 2018, 99.67),
#  ('Paraguay', 2019, 99.67),
#  ('Paraguay', 2020, 99.67),
#  ('Peru', 2015, 86.0),
#  ('Peru', 2016, 87.33),
#  ('Peru', 2017, 87.67),
#  ('Peru', 2018, 88.67),
#  ('Peru', 2019, 89.33),
#  ('Peru', 2020, 90.33),
#  ('Suriname', 2015, 95.0),
#  ('Suriname', 2016, 95.33),
#  ('Suriname', 2017, 96.33),
#  ('Suriname', 2018, 96.67),
#  ('Suriname', 2019, 97.33),
#  ('Suriname', 2020, 98.0),
#  ('Uruguay', 2015, 96.67),
#  ('Uruguay', 2016, 97.33),
#  ('Uruguay', 2017, 98.0),
#  ('Uruguay', 2018, 98.0),
#  ('Uruguay', 2019, 98.0),
#  ('Uruguay', 2020, 98.0),
#  ('Venezuela (Bolivarian Republic of)', 2015, 95.0),
#  ('Venezuela (Bolivarian Republic of)', 2016, 94.0),
#  ('Venezuela (Bolivarian Republic of)', 2017, 94.0),
#  ('Venezuela (Bolivarian Republic of)', 2018, 94.0),
#  ('Venezuela (Bolivarian Republic of)', 2019, 94.0),
#  ('Venezuela (Bolivarian Republic of)', 2020, 94.0),
#  ('Algeria', 2015, 92.0),
#  ('Algeria', 2016, 93.0),
#  ('Algeria', 2017, 93.0),
#  ('Algeria', 2018, 93.0),
#  ('Algeria', 2019, 93.33),
#  ('Algeria', 2020, 93.33),
#  ('Egypt', 2015, 99.33),
#  ('Egypt', 2016, 99.33),
#  ('Egypt', 2017, 99.33),
#  ('Egypt', 2018, 99.33),
#  ('Egypt', 2019, 99.33),
#  ('Egypt', 2020, 99.33),
#  ('Libya', 2015, 97.0),
#  ('Libya', 2016, 98.0),
#  ('Libya', 2017, 99.0),
#  ('Libya', 2018, 100.0),
#  ('Libya', 2019, 100.0),
#  ('Libya', 2020, 100.0),
#  ('Morocco', 2015, 81.33),
#  ('Morocco', 2016, 83.0),
#  ('Morocco', 2017, 84.0),
#  ('Morocco', 2018, 85.67),
#  ('Morocco', 2019, 87.33),
#  ('Morocco', 2020, 88.33),
#  ('Sudan', 2015, 61.33),
#  ('Sudan', 2016, 62.33),
#  ('Sudan', 2017, 62.33),
#  ('Sudan', 2018, 62.33),
#  ('Sudan', 2019, 62.33),
#  ('Sudan', 2020, 62.33),
#  ('Tunisia', 2015, 93.33),
#  ('Tunisia', 2016, 93.67),
#  ('Tunisia', 2017, 94.67),
#  ('Tunisia', 2018, 95.67),
#  ('Tunisia', 2019, 96.0),
#  ('Tunisia', 2020, 97.0),
#  ('Armenia', 2015, 99.67),
#  ('Armenia', 2016, 99.67),
#  ('Armenia', 2017, 100.0),
#  ('Armenia', 2018, 100.0),
#  ('Armenia', 2019, 100.0),
#  ('Armenia', 2020, 100.0),
#  ('Azerbaijan', 2015, 91.67),
#  ('Azerbaijan', 2016, 92.33),
#  ('Azerbaijan', 2017, 93.67),
#  ('Azerbaijan', 2018, 94.33),
#  ('Azerbaijan', 2019, 95.0),
#  ('Azerbaijan', 2020, 95.67),
#  ('Bahrain', 2015, 100.0),
#  ('Bahrain', 2016, 100.0),
#  ('Bahrain', 2017, 100.0),
#  ('Bahrain', 2018, 100.0),
#  ('Bahrain', 2019, 100.0),
#  ('Bahrain', 2020, 100.0),
#  ('Cyprus', 2015, 100.0),
#  ('Cyprus', 2016, 100.0),
#  ('Cyprus', 2017, 100.0),
#  ('Cyprus', 2018, 100.0),
#  ('Cyprus', 2019, 100.0),
#  ('Cyprus', 2020, 100.0),
#  ('Georgia', 2015, 95.33),
#  ('Georgia', 2016, 96.0),
#  ('Georgia', 2017, 96.67),
#  ('Georgia', 2018, 96.67),
#  ('Georgia', 2019, 96.67),
#  ('Georgia', 2020, 96.67),
#  ('Iraq', 2015, 92.33),
#  ('Iraq', 2016, 93.67),
#  ('Iraq', 2017, 94.67),
#  ('Iraq', 2018, 95.67),
#  ('Iraq', 2019, 97.0),
#  ('Iraq', 2020, 97.67),
#  ('Israel', 2015, 100.0),
#  ('Israel', 2016, 100.0),
#  ('Israel', 2017, 100.0),
#  ('Israel', 2018, 100.0),
#  ('Israel', 2019, 100.0),
#  ('Israel', 2020, 100.0),
#  ('Jordan', 2015, 98.33),
#  ('Jordan', 2016, 98.33),
#  ('Jordan', 2017, 98.33),
#  ('Jordan', 2018, 98.33),
#  ('Jordan', 2019, 98.33),
#  ('Jordan', 2020, 98.33),
#  ('Kuwait', 2015, 100.0),
#  ('Kuwait', 2016, 100.0),
#  ('Kuwait', 2017, 100.0),
#  ('Kuwait', 2018, 100.0),
#  ('Kuwait', 2019, 100.0),
#  ('Kuwait', 2020, 100.0),
#  ('Lebanon', 2015, 91.0),
#  ('Lebanon', 2016, 92.0),
#  ('Lebanon', 2017, 92.0),
#  ('Lebanon', 2018, 92.0),
#  ('Lebanon', 2019, 93.0),
#  ('Lebanon', 2020, 93.0),
#  ('Oman', 2015, 86.0),
#  ('Oman', 2016, 86.67),
#  ('Oman', 2017, 86.67),
#  ('Oman', 2018, 87.0),
#  ('Oman', 2019, 87.67),
#  ('Oman', 2020, 87.67),
#  ('Qatar', 2015, 100.0),
#  ('Qatar', 2016, 100.0),
#  ('Qatar', 2017, 100.0),
#  ('Qatar', 2018, 100.0),
#  ('Qatar', 2019, 100.0),
#  ('Qatar', 2020, 100.0),
#  ('Saudi Arabia', 2015, 100.0),
#  ('Saudi Arabia', 2016, 100.0),
#  ('Saudi Arabia', 2017, 100.0),
#  ('Saudi Arabia', 2018, 100.0),
#  ('Saudi Arabia', 2019, 100.0),
#  ('Saudi Arabia', 2020, 100.0),
#  ('State of Palestine', 2015, 96.0),
#  ('State of Palestine', 2016, 96.67),
#  ('State of Palestine', 2017, 97.0),
#  ('State of Palestine', 2018, 97.0),
#  ('State of Palestine', 2019, 97.67),
#  ('State of Palestine', 2020, 98.33),
#  ('Syrian Arab Republic', 2015, 93.33),
#  ('Syrian Arab Republic', 2016, 93.67),
#  ('Syrian Arab Republic', 2017, 93.67),
#  ('Syrian Arab Republic', 2018, 93.67),
#  ('Syrian Arab Republic', 2019, 93.67),
#  ('Syrian Arab Republic', 2020, 93.67),
#  ('Türkiye', 2015, 95.67),
#  ('Türkiye', 2016, 96.0),
#  ('Türkiye', 2017, 96.33),
#  ('Türkiye', 2018, 96.33),
#  ('Türkiye', 2019, 96.67),
#  ('Türkiye', 2020, 96.67),
#  ('United Arab Emirates', 2015, 100.0),
#  ('United Arab Emirates', 2016, 100.0),
#  ('United Arab Emirates', 2017, 100.0),
#  ('United Arab Emirates', 2018, 100.0),
#  ('United Arab Emirates', 2019, 100.0),
#  ('United Arab Emirates', 2020, 100.0),
#  ('Yemen', 2015, 59.0),
#  ('Yemen', 2016, 59.67),
#  ('Yemen', 2017, 60.33),
#  ('Yemen', 2018, 61.33),
#  ('Yemen', 2019, 62.33),
#  ('Yemen', 2020, 63.0),
#  ('Australia', 2015, 100.0),
#  ('Australia', 2016, 100.0),
#  ('Australia', 2017, 100.0),
#  ('Australia', 2018, 100.0),
#  ('Australia', 2019, 100.0),
#  ('Australia', 2020, 100.0),
#  ('New Zealand', 2015, 100.0),
#  ('New Zealand', 2016, 100.0),
#  ('New Zealand', 2017, 100.0),
#  ('New Zealand', 2018, 100.0),
#  ('New Zealand', 2019, 100.0),
#  ('New Zealand', 2020, 100.0),
#  ('Fiji', 2015, 93.67),
#  ('Fiji', 2016, 93.67),
#  ('Fiji', 2017, 93.67),
#  ('Fiji', 2018, 93.67),
#  ('Fiji', 2019, 93.67),
#  ('Fiji', 2020, 93.67),
#  ('New Caledonia', 2015, 98.0),
#  ('New Caledonia', 2016, 98.0),
#  ('New Caledonia', 2017, 99.0),
#  ('New Caledonia', 2018, 99.0),
#  ('New Caledonia', 2019, 99.0),
#  ('New Caledonia', 2020, 99.0),
#  ('Papua New Guinea', 2015, 53.67),
#  ('Papua New Guinea', 2016, 54.33),
#  ('Papua New Guinea', 2017, 55.0),
#  ('Papua New Guinea', 2018, 55.67),
#  ('Papua New Guinea', 2019, 56.33),
#  ('Papua New Guinea', 2020, 56.67),
#  ('Solomon Islands', 2015, 74.33),
#  ('Solomon Islands', 2016, 74.0),
#  ('Solomon Islands', 2017, 73.33),
#  ('Solomon Islands', 2018, 72.33),
#  ('Solomon Islands', 2019, 72.33),
#  ('Solomon Islands', 2020, 72.33),
#  ('Vanuatu', 2015, 92.0),
#  ('Vanuatu', 2016, 92.67),
#  ('Vanuatu', 2017, 93.0),
#  ('Vanuatu', 2018, 93.0),
#  ('Vanuatu', 2019, 93.0),
#  ('Vanuatu', 2020, 93.0),
#  ('Guam', 2015, 100.0),
#  ('Guam', 2016, 100.0),
#  ('Guam', 2017, 100.0),
#  ('Guam', 2018, 100.0),
#  ('Guam', 2019, 100.0),
#  ('Guam', 2020, 100.0),
#  ('Kiribati', 2015, 73.67),
#  ('Kiribati', 2016, 74.33),
#  ('Kiribati', 2017, 75.0),
#  ('Kiribati', 2018, 75.33),
#  ('Kiribati', 2019, 76.0),
#  ('Kiribati', 2020, 77.0),
#  ('Marshall Islands', 2015, 89.33),
#  ('Marshall Islands', 2016, 89.67),
#  ('Marshall Islands', 2017, 89.67),
#  ('Marshall Islands', 2018, 90.0),
#  ('Marshall Islands', 2019, 90.0),
#  ('Marshall Islands', 2020, 90.0),
#  ('Micronesia (Federated States of)', 2015, 88.0),
#  ('Micronesia (Federated States of)', 2016, 88.0),
#  ('Micronesia (Federated States of)', 2017, 88.0),
#  ('Micronesia (Federated States of)', 2018, 88.0),
#  ('Micronesia (Federated States of)', 2019, 88.0),
#  ('Nauru', 2015, 100.0),
#  ('Nauru', 2016, 100.0),
#  ('Nauru', 2017, 100.0),
#  ('Nauru', 2018, 100.0),
#  ('Nauru', 2019, 100.0),
#  ('Nauru', 2020, 100.0),
#  ('Northern Mariana Islands', 2015, 100.0),
#  ('Northern Mariana Islands', 2016, 100.0),
#  ('Northern Mariana Islands', 2017, 100.0),
#  ('Northern Mariana Islands', 2018, 100.0),
#  ('Northern Mariana Islands', 2019, 100.0),
#  ('Northern Mariana Islands', 2020, 100.0),
#  ('Palau', 2015, 100.0),
#  ('Palau', 2016, 100.0),
#  ('Palau', 2017, 100.0),
#  ('Palau', 2018, 100.0),
#  ('Palau', 2019, 100.0),
#  ('Palau', 2020, 100.0),
#  ('American Samoa', 2015, 100.0),
#  ('American Samoa', 2016, 100.0),
#  ('American Samoa', 2017, 100.0),
#  ('American Samoa', 2018, 100.0),
#  ('American Samoa', 2019, 100.0),
#  ('American Samoa', 2020, 100.0),
#  ('Cook Islands', 2015, 100.0),
#  ('Cook Islands', 2016, 100.0),
#  ('Cook Islands', 2017, 100.0),
#  ('Cook Islands', 2018, 100.0),
#  ('Cook Islands', 2019, 100.0),
#  ('Cook Islands', 2020, 100.0),
#  ('French Polynesia', 2015, 100.0),
#  ('French Polynesia', 2016, 100.0),
#  ('French Polynesia', 2017, 100.0),
#  ('French Polynesia', 2018, 100.0),
#  ('French Polynesia', 2019, 100.0),
#  ('French Polynesia', 2020, 100.0),
#  ('Niue', 2015, 98.0),
#  ('Niue', 2016, 97.0),
#  ('Niue', 2017, 97.0),
#  ('Niue', 2018, 97.0),
#  ('Niue', 2019, 97.0),
#  ('Niue', 2020, 97.0),
#  ('Samoa', 2015, 91.0),
#  ('Samoa', 2016, 92.0),
#  ('Samoa', 2017, 92.0),
#  ('Samoa', 2018, 92.0),
#  ('Samoa', 2019, 92.0),
#  ('Samoa', 2020, 92.0),
#  ('Tokelau', 2015, 99.0),
#  ('Tokelau', 2016, 100.0),
#  ('Tokelau', 2017, 100.0),
#  ('Tokelau', 2018, 100.0),
#  ('Tokelau', 2019, 100.0),
#  ('Tokelau', 2020, 100.0),
#  ('Tonga', 2015, 98.67),
#  ('Tonga', 2016, 98.67),
#  ('Tonga', 2017, 98.67),
#  ('Tonga', 2018, 98.67),
#  ('Tonga', 2019, 98.67),
#  ('Tonga', 2020, 99.0),
#  ('Tuvalu', 2015, 100.0),
#  ('Tuvalu', 2016, 100.0),
#  ('Tuvalu', 2017, 100.0),
#  ('Tuvalu', 2018, 100.0),
#  ('Tuvalu', 2019, 100.0),
#  ('Tuvalu', 2020, 100.0),
#  ('Wallis and Futuna Islands', 2015, 99.0),
#  ('Wallis and Futuna Islands', 2016, 99.0),
#  ('Wallis and Futuna Islands', 2017, 99.0),
#  ('Wallis and Futuna Islands', 2018, 99.0),
#  ('Wallis and Futuna Islands', 2019, 99.0),
#  ('Wallis and Futuna Islands', 2020, 99.0),
#  ('Burundi', 2015, 68.33),
#  ('Burundi', 2016, 68.33),
#  ('Burundi', 2017, 69.33),
#  ('Burundi', 2018, 69.33),
#  ('Burundi', 2019, 70.33),
#  ('Burundi', 2020, 70.33),
#  ('Comoros', 2015, 81.67),
#  ('Comoros', 2016, 81.67),
#  ('Comoros', 2017, 81.67),
#  ('Comoros', 2018, 81.67),
#  ('Comoros', 2019, 81.67),
#  ('Djibouti', 2015, 69.67),
#  ('Djibouti', 2016, 69.33),
#  ('Djibouti', 2017, 69.33),
#  ('Djibouti', 2018, 69.33),
#  ('Djibouti', 2019, 69.0),
#  ('Djibouti', 2020, 69.0),
#  ('Eritrea', 2015, 56.33),
#  ('Eritrea', 2016, 56.67),
#  ('Ethiopia', 2015, 52.0),
#  ('Ethiopia', 2016, 53.33),
#  ('Ethiopia', 2017, 54.67),
#  ('Ethiopia', 2018, 55.67),
#  ('Ethiopia', 2019, 57.0),
#  ('Ethiopia', 2020, 58.0),
#  ('Kenya', 2015, 64.33),
#  ('Kenya', 2016, 65.0),
#  ('Kenya', 2017, 65.67),
#  ('Kenya', 2018, 65.67),
#  ('Kenya', 2019, 66.33),
#  ('Kenya', 2020, 67.0),
#  ('Madagascar', 2015, 53.33),
#  ('Madagascar', 2016, 54.0),
#  ('Madagascar', 2017, 54.67),
#  ('Madagascar', 2018, 55.33),
#  ('Madagascar', 2019, 56.0),
#  ('Madagascar', 2020, 56.33),
#  ('Malawi', 2015, 71.33),
#  ('Malawi', 2016, 72.0),
#  ('Malawi', 2017, 72.67),
#  ('Malawi', 2018, 73.33),
#  ('Malawi', 2019, 73.67),
#  ('Malawi', 2020, 74.33),
#  ('Mauritius', 2015, 100.0),
#  ('Mauritius', 2016, 100.0),
#  ('Mauritius', 2017, 100.0),
#  ('Mauritius', 2018, 100.0),
#  ('Mauritius', 2019, 100.0),
#  ('Mauritius', 2020, 100.0),
#  ('Mayotte', 2015, 97.0),
#  ('Mayotte', 2016, 97.0),
#  ('Mayotte', 2017, 97.0),
#  ('Mayotte', 2018, 96.0),
#  ('Mayotte', 2019, 96.0),
#  ('Mayotte', 2020, 96.0),
#  ('Mozambique', 2015, 55.67),
#  ('Mozambique', 2016, 58.0),
#  ('Mozambique', 2017, 60.0),
#  ('Mozambique', 2018, 62.33),
#  ('Mozambique', 2019, 64.33),
#  ('Mozambique', 2020, 66.67),
#  ('Rwanda', 2015, 63.0),
#  ('Rwanda', 2016, 64.0),
#  ('Rwanda', 2017, 65.0),
#  ('Rwanda', 2018, 65.67),
#  ('Rwanda', 2019, 66.33),
#  ('Rwanda', 2020, 66.33),
#  ('Réunion', 2015, 100.0),
#  ('Réunion', 2016, 100.0),
#  ('Réunion', 2017, 100.0),
#  ('Réunion', 2018, 100.0),
#  ('Réunion', 2019, 100.0),
#  ('Réunion', 2020, 100.0),
#  ('Seychelles', 2015, 96.0),
#  ('Seychelles', 2016, 96.0),
#  ('Seychelles', 2017, 96.0),
#  ('Seychelles', 2018, 96.0),
#  ('Seychelles', 2019, 97.0),
#  ('Somalia', 2015, 50.67),
#  ('Somalia', 2016, 52.0),
#  ('Somalia', 2017, 53.33),
#  ('Somalia', 2018, 54.67),
#  ('Somalia', 2019, 56.33),
#  ('Somalia', 2020, 57.33),
#  ('South Sudan', 2015, 46.33),
#  ('South Sudan', 2016, 46.67),
#  ('South Sudan', 2017, 47.0),
#  ('South Sudan', 2018, 47.67),
#  ('South Sudan', 2019, 48.33),
#  ('South Sudan', 2020, 48.33),
#  ('Uganda', 2015, 55.0),
#  ('Uganda', 2016, 55.67),
#  ('Uganda', 2017, 57.0),
#  ('Uganda', 2018, 58.67),
#  ('Uganda', 2019, 59.33),
#  ('Uganda', 2020, 61.0),
#  ('United Republic of Tanzania', 2015, 58.33),
#  ('United Republic of Tanzania', 2016, 60.0),
#  ('United Republic of Tanzania', 2017, 61.67),
#  ('United Republic of Tanzania', 2018, 63.33),
#  ('United Republic of Tanzania', 2019, 64.67),
#  ('United Republic of Tanzania', 2020, 65.0),
#  ('Zambia', 2015, 63.67),
#  ('Zambia', 2016, 64.33),
#  ('Zambia', 2017, 64.67),
#  ('Zambia', 2018, 65.33),
#  ('Zambia', 2019, 66.33),
#  ('Zambia', 2020, 66.67),
#  ('Zimbabwe', 2015, 70.0),
#  ('Zimbabwe', 2016, 69.33),
#  ('Zimbabwe', 2017, 69.0),
#  ('Zimbabwe', 2018, 68.67),
#  ('Zimbabwe', 2019, 68.33),
#  ('Zimbabwe', 2020, 68.0),
#  ('Angola', 2015, 50.33),
#  ('Angola', 2016, 51.0),
#  ('Angola', 2017, 51.33),
#  ('Angola', 2018, 52.33),
#  ('Angola', 2019, 52.33),
#  ('Angola', 2020, 52.33),
#  ('Cameroon', 2015, 62.67),
#  ('Cameroon', 2016, 62.67),
#  ('Cameroon', 2017, 63.33),
#  ('Cameroon', 2018, 63.33),
#  ('Cameroon', 2019, 63.33),
#  ('Cameroon', 2020, 64.0),
#  ('Central African Republic', 2015, 44.0),
#  ('Central African Republic', 2016, 42.67),
#  ('Central African Republic', 2017, 41.33),
#  ('Central African Republic', 2018, 40.67),
#  ('Central African Republic', 2019, 39.33),
#  ('Central African Republic', 2020, 38.33),
#  ('Chad', 2015, 51.67),
#  ('Chad', 2016, 52.0),
#  ('Chad', 2017, 52.0),
#  ('Chad', 2018, 52.0),
#  ('Chad', 2019, 52.33),
#  ('Chad', 2020, 52.67),
#  ('Congo', 2015, 66.33),
#  ('Congo', 2016, 67.67),
#  ('Congo', 2017, 68.67),
#  ('Congo', 2018, 68.67),
#  ('Congo', 2019, 69.0),
#  ('Congo', 2020, 69.0),
#  ('Democratic Republic of the Congo', 2015, 45.33),
#  ('Democratic Republic of the Congo', 2016, 45.67),
#  ('Democratic Republic of the Congo', 2017, 46.0),
#  ('Democratic Republic of the Congo', 2018, 46.67),
#  ('Democratic Republic of the Congo', 2019, 47.0),
#  ('Democratic Republic of the Congo', 2020, 47.67),
#  ('Equatorial Guinea', 2015, 57.67),
#  ('Equatorial Guinea', 2016, 57.67),
#  ('Equatorial Guinea', 2017, 58.0),
#  ('Gabon', 2015, 72.0),
#  ('Gabon', 2016, 72.33),
#  ('Gabon', 2017, 73.0),
#  ('Gabon', 2018, 73.0),
#  ('Gabon', 2019, 73.33),
#  ('Gabon', 2020, 73.33),
#  ('Sao Tome and Principe', 2015, 76.0),
#  ('Sao Tome and Principe', 2016, 76.67),
#  ('Sao Tome and Principe', 2017, 77.0),
#  ('Sao Tome and Principe', 2018, 77.0),
#  ('Sao Tome and Principe', 2019, 77.33),
#  ('Sao Tome and Principe', 2020, 77.33),
#  ('Botswana', 2015, 85.67),
#  ('Botswana', 2016, 86.67),
#  ('Botswana', 2017, 87.67),
#  ('Botswana', 2018, 88.33),
#  ('Botswana', 2019, 89.67),
#  ('Botswana', 2020, 89.67),
#  ('Eswatini', 2015, 73.33),
#  ('Eswatini', 2016, 74.0),
#  ('Eswatini', 2017, 75.0),
#  ('Eswatini', 2018, 75.67),
#  ('Eswatini', 2019, 76.67),
#  ('Eswatini', 2020, 76.67),
#  ('Lesotho', 2015, 74.67),
#  ('Lesotho', 2016, 75.0),
#  ('Lesotho', 2017, 75.33),
#  ('Lesotho', 2018, 76.0),
#  ('Lesotho', 2019, 76.0),
#  ('Lesotho', 2020, 76.33),
#  ('Namibia', 2015, 83.33),
#  ('Namibia', 2016, 83.0),
#  ('Namibia', 2017, 83.33),
#  ('Namibia', 2018, 83.67),
#  ('Namibia', 2019, 83.67),
#  ('Namibia', 2020, 83.67),
#  ('South Africa', 2015, 90.0),
#  ('South Africa', 2016, 90.33),
#  ('South Africa', 2017, 91.0),
#  ('South Africa', 2018, 91.33),
#  ('South Africa', 2019, 91.67),
#  ('South Africa', 2020, 92.0),
#  ('Benin', 2015, 65.33),
#  ('Benin', 2016, 65.33),
#  ('Benin', 2017, 65.33),
#  ('Benin', 2018, 65.67),
#  ('Benin', 2019, 65.33),
#  ('Benin', 2020, 65.33),
#  ('Burkina Faso', 2015, 56.33),
#  ('Burkina Faso', 2016, 56.0),
#  ('Burkina Faso', 2017, 55.0),
#  ('Burkina Faso', 2018, 54.33),
#  ('Burkina Faso', 2019, 54.0),
#  ('Burkina Faso', 2020, 53.33),
#  ('Cabo Verde', 2015, 83.33),
#  ('Cabo Verde', 2016, 84.33),
#  ('Cabo Verde', 2017, 85.33),
#  ('Cabo Verde', 2018, 86.0),
#  ('Cabo Verde', 2019, 86.67),
#  ('Cabo Verde', 2020, 87.33),
#  ("Côte d'Ivoire", 2015, 71.33),
#  ("Côte d'Ivoire", 2016, 71.0),
#  ("Côte d'Ivoire", 2017, 71.0),
#  ("Côte d'Ivoire", 2018, 71.0),
#  ("Côte d'Ivoire", 2019, 70.67),
#  ("Côte d'Ivoire", 2020, 70.67),
#  ('Gambia', 2015, 78.0),
#  ('Gambia', 2016, 78.33),
#  ('Gambia', 2017, 78.67),
#  ('Gambia', 2018, 78.67),
#  ('Gambia', 2019, 79.33),
#  ('Gambia', 2020, 79.33),
#  ('Ghana', 2015, 79.33),
#  ('Ghana', 2016, 80.33),
#  ('Ghana', 2017, 81.33),
#  ('Ghana', 2018, 82.67),
#  ('Ghana', 2019, 83.67),
#  ('Ghana', 2020, 84.67),
#  ('Guinea', 2015, 67.0),
#  ('Guinea', 2016, 67.0),
#  ('Guinea', 2017, 67.33),
#  ('Guinea', 2018, 67.0),
#  ('Guinea', 2019, 67.0),
#  ('Guinea', 2020, 67.33),
#  ('Guinea-Bissau', 2015, 60.0),
#  ('Guinea-Bissau', 2016, 60.33),
#  ('Guinea-Bissau', 2017, 60.0),
#  ('Guinea-Bissau', 2018, 60.0),
#  ('Guinea-Bissau', 2019, 60.0),
#  ('Guinea-Bissau', 2020, 60.0),
#  ('Liberia', 2015, 72.67),
#  ('Liberia', 2016, 73.0),
#  ('Liberia', 2017, 74.0),
#  ('Liberia', 2018, 74.0),
#  ('Liberia', 2019, 75.0),
#  ('Liberia', 2020, 75.0),
#  ...]

# %% [markdown]
# ### 1. Order countries based on their water access levels per year.
#
# Use the `ROW_NUMBER()` function to order the countries based on their water access levels per year.

# %%
# %%sql
# SELECT
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services,
#     ROW_NUMBER()OVER(PARTITION BY Time_period
#         ORDER BY Pct_managed_drinking_water_services DESC) AS Rank_water_services
# FROM
#     united_nations.Access_to_basic_services;
# Out:
#  * mysql+pymysql://cybergod:***@localhost:3306/united_nations
# 1048 rows affected.
# [('Singapore', 2015, 100.0, 1),
#  ('Bermuda', 2015, 100.0, 2),
#  ('Greenland', 2015, 100.0, 3),
#  ('British Virgin Islands', 2015, 100.0, 4),
#  ('Guadeloupe', 2015, 100.0, 5),
#  ('Martinique', 2015, 100.0, 6),
#  ('Saint Barthélemy', 2015, 100.0, 7),
#  ('Saint Martin (French Part)', 2015, 100.0, 8),
#  ('Bahrain', 2015, 100.0, 9),
#  ('Cyprus', 2015, 100.0, 10),
#  ('Israel', 2015, 100.0, 11),
#  ('Kuwait', 2015, 100.0, 12),
#  ('Qatar', 2015, 100.0, 13),
#  ('Saudi Arabia', 2015, 100.0, 14),
#  ('United Arab Emirates', 2015, 100.0, 15),
#  ('Australia', 2015, 100.0, 16),
#  ('New Zealand', 2015, 100.0, 17),
#  ('Guam', 2015, 100.0, 18),
#  ('Nauru', 2015, 100.0, 19),
#  ('Northern Mariana Islands', 2015, 100.0, 20),
#  ('Palau', 2015, 100.0, 21),
#  ('American Samoa', 2015, 100.0, 22),
#  ('Cook Islands', 2015, 100.0, 23),
#  ('French Polynesia', 2015, 100.0, 24),
#  ('Tuvalu', 2015, 100.0, 25),
#  ('Mauritius', 2015, 100.0, 26),
#  ('Réunion', 2015, 100.0, 27),
#  ('Brunei Darussalam', 2015, 99.67, 28),
#  ('Armenia', 2015, 99.67, 29),
#  ('Thailand', 2015, 99.33, 30),
#  ('Egypt', 2015, 99.33, 31),
#  ('Maldives', 2015, 99.0, 32),
#  ('Japan', 2015, 99.0, 33),
#  ('Republic of Korea', 2015, 99.0, 34),
#  ('Canada', 2015, 99.0, 35),
#  ('United States of America', 2015, 99.0, 36),
#  ('Bahamas', 2015, 99.0, 37),
#  ('Curaçao', 2015, 99.0, 38),
#  ('Puerto Rico', 2015, 99.0, 39),
#  ('Saint Kitts and Nevis', 2015, 99.0, 40),
#  ('United States Virgin Islands', 2015, 99.0, 41),
#  ('Costa Rica', 2015, 99.0, 42),
#  ('Chile', 2015, 99.0, 43),
#  ('Tokelau', 2015, 99.0, 44),
#  ('Wallis and Futuna Islands', 2015, 99.0, 45),
#  ('Saint Helena', 2015, 99.0, 46),
#  ('Tonga', 2015, 98.67, 47),
#  ('Jordan', 2015, 98.33, 48),
#  ('Aruba', 2015, 98.0, 49),
#  ('Barbados', 2015, 98.0, 50),
#  ('Montserrat', 2015, 98.0, 51),
#  ('Trinidad and Tobago', 2015, 98.0, 52),
#  ('New Caledonia', 2015, 98.0, 53),
#  ('Niue', 2015, 98.0, 54),
#  ('Turkmenistan', 2015, 97.67, 55),
#  ('Uzbekistan', 2015, 97.67, 56),
#  ('Bangladesh', 2015, 97.33, 57),
#  ('Belize', 2015, 97.33, 58),
#  ('Argentina', 2015, 97.33, 59),
#  ('Anguilla', 2015, 97.0, 60),
#  ('Antigua and Barbuda', 2015, 97.0, 61),
#  ('Libya', 2015, 97.0, 62),
#  ('Mayotte', 2015, 97.0, 63),
#  ('Mexico', 2015, 96.67, 64),
#  ('Uruguay', 2015, 96.67, 65),
#  ('Bhutan', 2015, 96.33, 66),
#  ('Paraguay', 2015, 96.33, 67),
#  ('Cayman Islands', 2015, 96.0, 68),
#  ('Grenada', 2015, 96.0, 69),
#  ('Saint Lucia', 2015, 96.0, 70),
#  ('Guyana', 2015, 96.0, 71),
#  ('State of Palestine', 2015, 96.0, 72),
#  ('Seychelles', 2015, 96.0, 73),
#  ('Iran (Islamic Republic of)', 2015, 95.67, 74),
#  ('Malaysia', 2015, 95.67, 75),
#  ('Türkiye', 2015, 95.67, 76),
#  ('Brazil', 2015, 95.33, 77),
#  ('Georgia', 2015, 95.33, 78),
#  ('Dominica', 2015, 95.0, 79),
#  ('Saint Vincent and the Grenadines', 2015, 95.0, 80),
#  ('Sint Maarten (Dutch part)', 2015, 95.0, 81),
#  ('Suriname', 2015, 95.0, 82),
#  ('Venezuela (Bolivarian Republic of)', 2015, 95.0, 83),
#  ('Kazakhstan', 2015, 94.67, 84),
#  ("Democratic People's Republic of Korea", 2015, 94.67, 85),
#  ('Cuba', 2015, 94.67, 86),
#  ('Dominican Republic', 2015, 94.33, 87),
#  ('El Salvador', 2015, 94.33, 88),
#  ('Viet Nam', 2015, 94.0, 89),
#  ('Turks and Caicos Islands', 2015, 94.0, 90),
#  ('French Guiana', 2015, 94.0, 91),
#  ('Fiji', 2015, 93.67, 92),
#  ('Tunisia', 2015, 93.33, 93),
#  ('Syrian Arab Republic', 2015, 93.33, 94),
#  ('Colombia', 2015, 93.0, 95),
#  ('Honduras', 2015, 92.67, 96),
#  ('Iraq', 2015, 92.33, 97),
#  ('Sri Lanka', 2015, 92.0, 98),
#  ('Philippines', 2015, 92.0, 99),
#  ('Guatemala', 2015, 92.0, 100),
#  ('Algeria', 2015, 92.0, 101),
#  ('Vanuatu', 2015, 92.0, 102),
#  ('Panama', 2015, 91.67, 103),
#  ('Ecuador', 2015, 91.67, 104),
#  ('Azerbaijan', 2015, 91.67, 105),
#  ('China', 2015, 91.33, 106),
#  ('Saint Pierre and Miquelon', 2015, 91.0, 107),
#  ('Falkland Islands (Malvinas)', 2015, 91.0, 108),
#  ('Lebanon', 2015, 91.0, 109),
#  ('Samoa', 2015, 91.0, 110),
#  ('Pakistan', 2015, 90.0, 111),
#  ('Jamaica', 2015, 90.0, 112),
#  ('South Africa', 2015, 90.0, 113),
#  ('Kyrgyzstan', 2015, 89.67, 114),
#  ('Marshall Islands', 2015, 89.33, 115),
#  ('India', 2015, 89.0, 116),
#  ('Nepal', 2015, 88.33, 117),
#  ('Indonesia', 2015, 88.33, 118),
#  ('Micronesia (Federated States of)', 2015, 88.0, 119),
#  ('Bolivia (Plurinational State of)', 2015, 87.33, 120),
#  ('Peru', 2015, 86.0, 121),
#  ('Oman', 2015, 86.0, 122),
#  ('Botswana', 2015, 85.67, 123),
#  ('Namibia', 2015, 83.33, 124),
#  ('Cabo Verde', 2015, 83.33, 125),
#  ('Comoros', 2015, 81.67, 126),
#  ('Morocco', 2015, 81.33, 127),
#  ('Tajikistan', 2015, 80.33, 128),
#  ("Lao People's Democratic Republic", 2015, 79.67, 129),
#  ('Senegal', 2015, 79.67, 130),
#  ('Nicaragua', 2015, 79.33, 131),
#  ('Ghana', 2015, 79.33, 132),
#  ('Timor-Leste', 2015, 78.0, 133),
#  ('Gambia', 2015, 78.0, 134),
#  ('Myanmar', 2015, 76.33, 135),
#  ('Sao Tome and Principe', 2015, 76.0, 136),
#  ('Mali', 2015, 76.0, 137),
#  ('Mongolia', 2015, 75.67, 138),
#  ('Lesotho', 2015, 74.67, 139),
#  ('Solomon Islands', 2015, 74.33, 140),
#  ('Kiribati', 2015, 73.67, 141),
#  ('Cambodia', 2015, 73.33, 142),
#  ('Eswatini', 2015, 73.33, 143),
#  ('Liberia', 2015, 72.67, 144),
#  ('Gabon', 2015, 72.0, 145),
#  ('Malawi', 2015, 71.33, 146),
#  ("Côte d'Ivoire", 2015, 71.33, 147),
#  ('Zimbabwe', 2015, 70.0, 148),
#  ('Djibouti', 2015, 69.67, 149),
#  ('Nigeria', 2015, 69.0, 150),
#  ('Burundi', 2015, 68.33, 151),
#  ('Afghanistan', 2015, 67.0, 152),
#  ('Guinea', 2015, 67.0, 153),
#  ('Mauritania', 2015, 66.67, 154),
#  ('Congo', 2015, 66.33, 155),
#  ('Togo', 2015, 66.33, 156),
#  ('Benin', 2015, 65.33, 157),
#  ('Kenya', 2015, 64.33, 158),
#  ('Haiti', 2015, 64.0, 159),
#  ('Zambia', 2015, 63.67, 160),
#  ('Rwanda', 2015, 63.0, 161),
#  ('Cameroon', 2015, 62.67, 162),
#  ('Sudan', 2015, 61.33, 163),
#  ('Guinea-Bissau', 2015, 60.0, 164),
#  ('Sierra Leone', 2015, 60.0, 165),
#  ('Yemen', 2015, 59.0, 166),
#  ('United Republic of Tanzania', 2015, 58.33, 167),
#  ('Equatorial Guinea', 2015, 57.67, 168),
#  ('Niger', 2015, 56.67, 169),
#  ('Eritrea', 2015, 56.33, 170),
#  ('Burkina Faso', 2015, 56.33, 171),
#  ('Mozambique', 2015, 55.67, 172),
#  ('Uganda', 2015, 55.0, 173),
#  ('Papua New Guinea', 2015, 53.67, 174),
#  ('Madagascar', 2015, 53.33, 175),
#  ('Ethiopia', 2015, 52.0, 176),
#  ('Chad', 2015, 51.67, 177),
#  ('Somalia', 2015, 50.67, 178),
#  ('Angola', 2015, 50.33, 179),
#  ('South Sudan', 2015, 46.33, 180),
#  ('Democratic Republic of the Congo', 2015, 45.33, 181),
#  ('Central African Republic', 2015, 44.0, 182),
#  ('Republic of Korea', 2016, 100.0, 1),
#  ('Brunei Darussalam', 2016, 100.0, 2),
#  ('Singapore', 2016, 100.0, 3),
#  ('Bermuda', 2016, 100.0, 4),
#  ('Greenland', 2016, 100.0, 5),
#  ('British Virgin Islands', 2016, 100.0, 6),
#  ('Guadeloupe', 2016, 100.0, 7),
#  ('Martinique', 2016, 100.0, 8),
#  ('Puerto Rico', 2016, 100.0, 9),
#  ('Saint Barthélemy', 2016, 100.0, 10),
#  ('Saint Martin (French Part)', 2016, 100.0, 11),
#  ('Bahrain', 2016, 100.0, 12),
#  ('Cyprus', 2016, 100.0, 13),
#  ('Israel', 2016, 100.0, 14),
#  ('Kuwait', 2016, 100.0, 15),
#  ('Qatar', 2016, 100.0, 16),
#  ('Saudi Arabia', 2016, 100.0, 17),
#  ('United Arab Emirates', 2016, 100.0, 18),
#  ('Australia', 2016, 100.0, 19),
#  ('New Zealand', 2016, 100.0, 20),
#  ('Guam', 2016, 100.0, 21),
#  ('Nauru', 2016, 100.0, 22),
#  ('Northern Mariana Islands', 2016, 100.0, 23),
#  ('Palau', 2016, 100.0, 24),
#  ('American Samoa', 2016, 100.0, 25),
#  ('Cook Islands', 2016, 100.0, 26),
#  ('French Polynesia', 2016, 100.0, 27),
#  ('Tokelau', 2016, 100.0, 28),
#  ('Tuvalu', 2016, 100.0, 29),
#  ('Mauritius', 2016, 100.0, 30),
#  ('Réunion', 2016, 100.0, 31),
#  ('Costa Rica', 2016, 99.67, 32),
#  ('Chile', 2016, 99.67, 33),
#  ('Armenia', 2016, 99.67, 34),
#  ('Thailand', 2016, 99.33, 35),
#  ('United States of America', 2016, 99.33, 36),
#  ('Egypt', 2016, 99.33, 37),
#  ('Maldives', 2016, 99.0, 38),
#  ('Japan', 2016, 99.0, 39),
#  ('Canada', 2016, 99.0, 40),
#  ('Bahamas', 2016, 99.0, 41),
#  ('Curaçao', 2016, 99.0, 42),
#  ('Saint Kitts and Nevis', 2016, 99.0, 43),
#  ('Trinidad and Tobago', 2016, 99.0, 44),
#  ('United States Virgin Islands', 2016, 99.0, 45),
#  ('Wallis and Futuna Islands', 2016, 99.0, 46),
#  ('Saint Helena', 2016, 99.0, 47),
#  ('Tonga', 2016, 98.67, 48),
#  ('Jordan', 2016, 98.33, 49),
#  ('Turkmenistan', 2016, 98.0, 50),
#  ('Aruba', 2016, 98.0, 51),
#  ('Barbados', 2016, 98.0, 52),
#  ('Montserrat', 2016, 98.0, 53),
#  ('Libya', 2016, 98.0, 54),
#  ('New Caledonia', 2016, 98.0, 55),
#  ('Uzbekistan', 2016, 97.67, 56),
#  ('Belize', 2016, 97.67, 57),
#  ('Paraguay', 2016, 97.67, 58),
#  ('Bangladesh', 2016, 97.33, 59),
#  ('Mexico', 2016, 97.33, 60),
#  ('Argentina', 2016, 97.33, 61),
#  ('Uruguay', 2016, 97.33, 62),
#  ('Bhutan', 2016, 97.0, 63),
#  ('Anguilla', 2016, 97.0, 64),
#  ('Antigua and Barbuda', 2016, 97.0, 65),
#  ('Niue', 2016, 97.0, 66),
#  ('Mayotte', 2016, 97.0, 67),
#  ('Guyana', 2016, 96.67, 68),
#  ('State of Palestine', 2016, 96.67, 69),
#  ('Saint Lucia', 2016, 96.33, 70),
#  ('Iran (Islamic Republic of)', 2016, 96.0, 71),
#  ('Cayman Islands', 2016, 96.0, 72),
#  ('Grenada', 2016, 96.0, 73),
#  ('Georgia', 2016, 96.0, 74),
#  ('Türkiye', 2016, 96.0, 75),
#  ('Seychelles', 2016, 96.0, 76),
#  ('Malaysia', 2016, 95.67, 77),
#  ('El Salvador', 2016, 95.33, 78),
#  ('Brazil', 2016, 95.33, 79),
#  ('Suriname', 2016, 95.33, 80),
#  ('Viet Nam', 2016, 95.0, 81),
#  ('Cuba', 2016, 95.0, 82),
#  ('Dominica', 2016, 95.0, 83),
#  ('Saint Vincent and the Grenadines', 2016, 95.0, 84),
#  ('Sint Maarten (Dutch part)', 2016, 95.0, 85),
#  ('Kazakhstan', 2016, 94.67, 86),
#  ('Dominican Republic', 2016, 94.67, 87),
#  ("Democratic People's Republic of Korea", 2016, 94.33, 88),
#  ('Turks and Caicos Islands', 2016, 94.0, 89),
#  ('French Guiana', 2016, 94.0, 90),
#  ('Venezuela (Bolivarian Republic of)', 2016, 94.0, 91),
#  ('Colombia', 2016, 93.67, 92),
#  ('Tunisia', 2016, 93.67, 93),
#  ('Iraq', 2016, 93.67, 94),
#  ('Syrian Arab Republic', 2016, 93.67, 95),
#  ('Fiji', 2016, 93.67, 96),
#  ('Honduras', 2016, 93.33, 97),
#  ('Sri Lanka', 2016, 93.0, 98),
#  ('Algeria', 2016, 93.0, 99),
#  ('Philippines', 2016, 92.67, 100),
#  ('Vanuatu', 2016, 92.67, 101),
#  ('Guatemala', 2016, 92.33, 102),
#  ('Ecuador', 2016, 92.33, 103),
#  ('Azerbaijan', 2016, 92.33, 104),
#  ('Lebanon', 2016, 92.0, 105),
#  ('Samoa', 2016, 92.0, 106),
#  ('Panama', 2016, 91.67, 107),
#  ('China', 2016, 91.33, 108),
#  ('Saint Pierre and Miquelon', 2016, 91.0, 109),
#  ('Falkland Islands (Malvinas)', 2016, 91.0, 110),
#  ('Kyrgyzstan', 2016, 90.33, 111),
#  ('Jamaica', 2016, 90.33, 112),
#  ('South Africa', 2016, 90.33, 113),
#  ('Pakistan', 2016, 90.0, 114),
#  ('Marshall Islands', 2016, 89.67, 115),
#  ('India', 2016, 89.33, 116),
#  ('Indonesia', 2016, 89.0, 117),
#  ('Nepal', 2016, 88.67, 118),
#  ('Bolivia (Plurinational State of)', 2016, 88.0, 119),
#  ('Micronesia (Federated States of)', 2016, 88.0, 120),
#  ('Peru', 2016, 87.33, 121),
#  ('Oman', 2016, 86.67, 122),
#  ('Botswana', 2016, 86.67, 123),
#  ('Cabo Verde', 2016, 84.33, 124),
#  ('Morocco', 2016, 83.0, 125),
#  ('Namibia', 2016, 83.0, 126),
#  ("Lao People's Democratic Republic", 2016, 82.0, 127),
#  ('Comoros', 2016, 81.67, 128),
#  ('Tajikistan', 2016, 81.33, 129),
#  ('Timor-Leste', 2016, 80.67, 130),
#  ('Senegal', 2016, 80.67, 131),
#  ('Ghana', 2016, 80.33, 132),
#  ('Nicaragua', 2016, 79.0, 133),
#  ('Myanmar', 2016, 78.33, 134),
#  ('Gambia', 2016, 78.33, 135),
#  ('Mali', 2016, 77.67, 136),
#  ('Mongolia', 2016, 77.0, 137),
#  ('Sao Tome and Principe', 2016, 76.67, 138),
#  ('Lesotho', 2016, 75.0, 139),
#  ('Kiribati', 2016, 74.33, 140),
#  ('Solomon Islands', 2016, 74.0, 141),
#  ('Eswatini', 2016, 74.0, 142),
#  ('Cambodia', 2016, 73.67, 143),
#  ('Liberia', 2016, 73.0, 144),
#  ('Gabon', 2016, 72.33, 145),
#  ('Malawi', 2016, 72.0, 146),
#  ("Côte d'Ivoire", 2016, 71.0, 147),
#  ('Nigeria', 2016, 71.0, 148),
#  ('Afghanistan', 2016, 69.67, 149),
#  ('Djibouti', 2016, 69.33, 150),
#  ('Zimbabwe', 2016, 69.33, 151),
#  ('Burundi', 2016, 68.33, 152),
#  ('Mauritania', 2016, 68.33, 153),
#  ('Congo', 2016, 67.67, 154),
#  ('Togo', 2016, 67.33, 155),
#  ('Guinea', 2016, 67.0, 156),
#  ('Benin', 2016, 65.33, 157),
#  ('Kenya', 2016, 65.0, 158),
#  ('Haiti', 2016, 64.33, 159),
#  ('Zambia', 2016, 64.33, 160),
#  ('Rwanda', 2016, 64.0, 161),
#  ('Cameroon', 2016, 62.67, 162),
#  ('Sudan', 2016, 62.33, 163),
#  ('Sierra Leone', 2016, 60.67, 164),
#  ('Guinea-Bissau', 2016, 60.33, 165),
#  ('United Republic of Tanzania', 2016, 60.0, 166),
#  ('Yemen', 2016, 59.67, 167),
#  ('Mozambique', 2016, 58.0, 168),
#  ('Equatorial Guinea', 2016, 57.67, 169),
#  ('Niger', 2016, 57.0, 170),
#  ('Eritrea', 2016, 56.67, 171),
#  ('Burkina Faso', 2016, 56.0, 172),
#  ('Uganda', 2016, 55.67, 173),
#  ('Papua New Guinea', 2016, 54.33, 174),
#  ('Madagascar', 2016, 54.0, 175),
#  ('Ethiopia', 2016, 53.33, 176),
#  ('Somalia', 2016, 52.0, 177),
#  ('Chad', 2016, 52.0, 178),
#  ('Angola', 2016, 51.0, 179),
#  ('South Sudan', 2016, 46.67, 180),
#  ('Democratic Republic of the Congo', 2016, 45.67, 181),
#  ('Central African Republic', 2016, 42.67, 182),
#  ('Republic of Korea', 2017, 100.0, 1),
#  ('Brunei Darussalam', 2017, 100.0, 2),
#  ('Singapore', 2017, 100.0, 3),
#  ('Thailand', 2017, 100.0, 4),
#  ('Bermuda', 2017, 100.0, 5),
#  ('Greenland', 2017, 100.0, 6),
#  ('British Virgin Islands', 2017, 100.0, 7),
#  ('Guadeloupe', 2017, 100.0, 8),
#  ('Martinique', 2017, 100.0, 9),
#  ('Puerto Rico', 2017, 100.0, 10),
#  ('Saint Barthélemy', 2017, 100.0, 11),
#  ('Saint Martin (French Part)', 2017, 100.0, 12),
#  ('Costa Rica', 2017, 100.0, 13),
#  ('Argentina', 2017, 100.0, 14),
#  ('Chile', 2017, 100.0, 15),
#  ('Armenia', 2017, 100.0, 16),
#  ('Bahrain', 2017, 100.0, 17),
#  ('Cyprus', 2017, 100.0, 18),
#  ('Israel', 2017, 100.0, 19),
#  ('Kuwait', 2017, 100.0, 20),
#  ('Qatar', 2017, 100.0, 21),
#  ('Saudi Arabia', 2017, 100.0, 22),
#  ('United Arab Emirates', 2017, 100.0, 23),
#  ('Australia', 2017, 100.0, 24),
#  ('New Zealand', 2017, 100.0, 25),
#  ('Guam', 2017, 100.0, 26),
#  ('Nauru', 2017, 100.0, 27),
#  ('Northern Mariana Islands', 2017, 100.0, 28),
#  ('Palau', 2017, 100.0, 29),
#  ('American Samoa', 2017, 100.0, 30),
#  ('Cook Islands', 2017, 100.0, 31),
#  ('French Polynesia', 2017, 100.0, 32),
#  ('Tokelau', 2017, 100.0, 33),
#  ('Tuvalu', 2017, 100.0, 34),
#  ('Mauritius', 2017, 100.0, 35),
#  ('Réunion', 2017, 100.0, 36),
#  ('United States of America', 2017, 99.67, 37),
#  ('Maldives', 2017, 99.33, 38),
#  ('Paraguay', 2017, 99.33, 39),
#  ('Egypt', 2017, 99.33, 40),
#  ('Japan', 2017, 99.0, 41),
#  ('Canada', 2017, 99.0, 42),
#  ('Bahamas', 2017, 99.0, 43),
#  ('Curaçao', 2017, 99.0, 44),
#  ('Saint Kitts and Nevis', 2017, 99.0, 45),
#  ('Trinidad and Tobago', 2017, 99.0, 46),
#  ('United States Virgin Islands', 2017, 99.0, 47),
#  ('Libya', 2017, 99.0, 48),
#  ('New Caledonia', 2017, 99.0, 49),
#  ('Wallis and Futuna Islands', 2017, 99.0, 50),
#  ('Saint Helena', 2017, 99.0, 51),
#  ('Turkmenistan', 2017, 98.67, 52),
#  ('Tonga', 2017, 98.67, 53),
#  ('Jordan', 2017, 98.33, 54),
#  ('Uzbekistan', 2017, 98.0, 55),
#  ('Barbados', 2017, 98.0, 56),
#  ('Montserrat', 2017, 98.0, 57),
#  ('Belize', 2017, 98.0, 58),
#  ('Mexico', 2017, 98.0, 59),
#  ('Uruguay', 2017, 98.0, 60),
#  ('Bangladesh', 2017, 97.33, 61),
#  ('Bhutan', 2017, 97.33, 62),
#  ('Anguilla', 2017, 97.0, 63),
#  ('Antigua and Barbuda', 2017, 97.0, 64),
#  ('State of Palestine', 2017, 97.0, 65),
#  ('Niue', 2017, 97.0, 66),
#  ('Mayotte', 2017, 97.0, 67),
#  ('Guyana', 2017, 96.67, 68),
#  ('Georgia', 2017, 96.67, 69),
#  ('Iran (Islamic Republic of)', 2017, 96.33, 70),
#  ('Saint Lucia', 2017, 96.33, 71),
#  ('Brazil', 2017, 96.33, 72),
#  ('Suriname', 2017, 96.33, 73),
#  ('Türkiye', 2017, 96.33, 74),
#  ('Grenada', 2017, 96.0, 75),
#  ('El Salvador', 2017, 96.0, 76),
#  ('Seychelles', 2017, 96.0, 77),
#  ('Malaysia', 2017, 95.67, 78),
#  ('Viet Nam', 2017, 95.67, 79),
#  ('Cuba', 2017, 95.33, 80),
#  ('Kazakhstan', 2017, 95.0, 81),
#  ('Dominica', 2017, 95.0, 82),
#  ('Saint Vincent and the Grenadines', 2017, 95.0, 83),
#  ('Sint Maarten (Dutch part)', 2017, 95.0, 84),
#  ('Dominican Republic', 2017, 94.67, 85),
#  ('Tunisia', 2017, 94.67, 86),
#  ('Iraq', 2017, 94.67, 87),
#  ("Democratic People's Republic of Korea", 2017, 94.0, 88),
#  ('Turks and Caicos Islands', 2017, 94.0, 89),
#  ('Colombia', 2017, 94.0, 90),
#  ('French Guiana', 2017, 94.0, 91),
#  ('Venezuela (Bolivarian Republic of)', 2017, 94.0, 92),
#  ('Sri Lanka', 2017, 93.67, 93),
#  ('Honduras', 2017, 93.67, 94),
#  ('Azerbaijan', 2017, 93.67, 95),
#  ('Syrian Arab Republic', 2017, 93.67, 96),
#  ('Fiji', 2017, 93.67, 97),
#  ('Philippines', 2017, 93.0, 98),
#  ('Algeria', 2017, 93.0, 99),
#  ('Vanuatu', 2017, 93.0, 100),
#  ('Guatemala', 2017, 92.67, 101),
#  ('Ecuador', 2017, 92.67, 102),
#  ('Panama', 2017, 92.33, 103),
#  ('China', 2017, 92.0, 104),
#  ('Lebanon', 2017, 92.0, 105),
#  ('Samoa', 2017, 92.0, 106),
#  ('Kyrgyzstan', 2017, 91.0, 107),
#  ('Saint Pierre and Miquelon', 2017, 91.0, 108),
#  ('Falkland Islands (Malvinas)', 2017, 91.0, 109),
#  ('South Africa', 2017, 91.0, 110),
#  ('Pakistan', 2017, 90.33, 111),
#  ('Jamaica', 2017, 90.33, 112),
#  ('India', 2017, 90.0, 113),
#  ('Indonesia', 2017, 89.67, 114),
#  ('Marshall Islands', 2017, 89.67, 115),
#  ('Nepal', 2017, 89.0, 116),
#  ('Bolivia (Plurinational State of)', 2017, 89.0, 117),
#  ('Micronesia (Federated States of)', 2017, 88.0, 118),
#  ('Peru', 2017, 87.67, 119),
#  ('Botswana', 2017, 87.67, 120),
#  ('Oman', 2017, 86.67, 121),
#  ('Cabo Verde', 2017, 85.33, 122),
#  ('Morocco', 2017, 84.0, 123),
#  ("Lao People's Democratic Republic", 2017, 83.33, 124),
#  ('Namibia', 2017, 83.33, 125),
#  ('Tajikistan', 2017, 82.33, 126),
#  ('Timor-Leste', 2017, 82.33, 127),
#  ('Comoros', 2017, 81.67, 128),
#  ('Senegal', 2017, 81.67, 129),
#  ('Ghana', 2017, 81.33, 130),
#  ('Myanmar', 2017, 80.33, 131),
#  ('Mali', 2017, 79.33, 132),
#  ('Nicaragua', 2017, 79.0, 133),
#  ('Gambia', 2017, 78.67, 134),
#  ('Mongolia', 2017, 78.0, 135),
#  ('Sao Tome and Principe', 2017, 77.0, 136),
#  ('Lesotho', 2017, 75.33, 137),
#  ('Kiribati', 2017, 75.0, 138),
#  ('Eswatini', 2017, 75.0, 139),
#  ('Cambodia', 2017, 74.33, 140),
#  ('Liberia', 2017, 74.0, 141),
#  ('Solomon Islands', 2017, 73.33, 142),
#  ('Gabon', 2017, 73.0, 143),
#  ('Malawi', 2017, 72.67, 144),
#  ('Afghanistan', 2017, 72.33, 145),
#  ('Nigeria', 2017, 72.33, 146),
#  ("Côte d'Ivoire", 2017, 71.0, 147),
#  ('Mauritania', 2017, 70.0, 148),
#  ('Burundi', 2017, 69.33, 149),
#  ('Djibouti', 2017, 69.33, 150),
#  ('Zimbabwe', 2017, 69.0, 151),
#  ('Congo', 2017, 68.67, 152),
#  ('Togo', 2017, 68.33, 153),
#  ('Guinea', 2017, 67.33, 154),
#  ('Kenya', 2017, 65.67, 155),
#  ('Benin', 2017, 65.33, 156),
#  ('Rwanda', 2017, 65.0, 157),
#  ('Zambia', 2017, 64.67, 158),
#  ('Haiti', 2017, 64.33, 159),
#  ('Cameroon', 2017, 63.33, 160),
#  ('Sudan', 2017, 62.33, 161),
#  ('United Republic of Tanzania', 2017, 61.67, 162),
#  ('Sierra Leone', 2017, 61.67, 163),
#  ('Yemen', 2017, 60.33, 164),
#  ('Mozambique', 2017, 60.0, 165),
#  ('Guinea-Bissau', 2017, 60.0, 166),
#  ('Equatorial Guinea', 2017, 58.0, 167),
#  ('Uganda', 2017, 57.0, 168),
#  ('Niger', 2017, 57.0, 169),
#  ('Papua New Guinea', 2017, 55.0, 170),
#  ('Burkina Faso', 2017, 55.0, 171),
#  ('Ethiopia', 2017, 54.67, 172),
#  ('Madagascar', 2017, 54.67, 173),
#  ('Somalia', 2017, 53.33, 174),
#  ('Chad', 2017, 52.0, 175),
#  ('Angola', 2017, 51.33, 176),
#  ('South Sudan', 2017, 47.0, 177),
#  ('Democratic Republic of the Congo', 2017, 46.0, 178),
#  ('Central African Republic', 2017, 41.33, 179),
#  ('Republic of Korea', 2018, 100.0, 1),
#  ('Brunei Darussalam', 2018, 100.0, 2),
#  ('Singapore', 2018, 100.0, 3),
#  ('Thailand', 2018, 100.0, 4),
#  ('Bermuda', 2018, 100.0, 5),
#  ('Greenland', 2018, 100.0, 6),
#  ('British Virgin Islands', 2018, 100.0, 7),
#  ('Guadeloupe', 2018, 100.0, 8),
#  ('Martinique', 2018, 100.0, 9),
#  ('Puerto Rico', 2018, 100.0, 10),
#  ('Saint Barthélemy', 2018, 100.0, 11),
#  ('Saint Martin (French Part)', 2018, 100.0, 12),
#  ('Costa Rica', 2018, 100.0, 13),
#  ('Argentina', 2018, 100.0, 14),
#  ('Chile', 2018, 100.0, 15),
#  ('Libya', 2018, 100.0, 16),
#  ('Armenia', 2018, 100.0, 17),
#  ('Bahrain', 2018, 100.0, 18),
#  ('Cyprus', 2018, 100.0, 19),
#  ('Israel', 2018, 100.0, 20),
#  ('Kuwait', 2018, 100.0, 21),
#  ('Qatar', 2018, 100.0, 22),
#  ('Saudi Arabia', 2018, 100.0, 23),
#  ('United Arab Emirates', 2018, 100.0, 24),
#  ('Australia', 2018, 100.0, 25),
#  ('New Zealand', 2018, 100.0, 26),
#  ('Guam', 2018, 100.0, 27),
#  ('Nauru', 2018, 100.0, 28),
#  ('Northern Mariana Islands', 2018, 100.0, 29),
#  ('Palau', 2018, 100.0, 30),
#  ('American Samoa', 2018, 100.0, 31),
#  ('Cook Islands', 2018, 100.0, 32),
#  ('French Polynesia', 2018, 100.0, 33),
#  ('Tokelau', 2018, 100.0, 34),
#  ('Tuvalu', 2018, 100.0, 35),
#  ('Mauritius', 2018, 100.0, 36),
#  ('Réunion', 2018, 100.0, 37),
#  ('United States of America', 2018, 99.67, 38),
#  ('Paraguay', 2018, 99.67, 39),
#  ('Turkmenistan', 2018, 99.33, 40),
#  ('Maldives', 2018, 99.33, 41),
#  ('Egypt', 2018, 99.33, 42),
#  ('Japan', 2018, 99.0, 43),
#  ('Canada', 2018, 99.0, 44),
#  ('Bahamas', 2018, 99.0, 45),
#  ('Barbados', 2018, 99.0, 46),
#  ('Trinidad and Tobago', 2018, 99.0, 47),
#  ('United States Virgin Islands', 2018, 99.0, 48),
#  ('New Caledonia', 2018, 99.0, 49),
#  ('Wallis and Futuna Islands', 2018, 99.0, 50),
#  ('Saint Helena', 2018, 99.0, 51),
#  ('Tonga', 2018, 98.67, 52),
#  ('Belize', 2018, 98.33, 53),
#  ('Mexico', 2018, 98.33, 54),
#  ('Jordan', 2018, 98.33, 55),
#  ('Uzbekistan', 2018, 98.0, 56),
#  ('Montserrat', 2018, 98.0, 57),
#  ('Uruguay', 2018, 98.0, 58),
#  ('Bangladesh', 2018, 97.33, 59),
#  ('Bhutan', 2018, 97.33, 60),
#  ('Saint Lucia', 2018, 97.0, 61),
#  ('El Salvador', 2018, 97.0, 62),
#  ('Brazil', 2018, 97.0, 63),
#  ('State of Palestine', 2018, 97.0, 64),
#  ('Niue', 2018, 97.0, 65),
#  ('Guyana', 2018, 96.67, 66),
#  ('Suriname', 2018, 96.67, 67),
#  ('Georgia', 2018, 96.67, 68),
#  ('Iran (Islamic Republic of)', 2018, 96.33, 69),
#  ('Viet Nam', 2018, 96.33, 70),
#  ('Türkiye', 2018, 96.33, 71),
#  ('Cuba', 2018, 96.0, 72),
#  ('Mayotte', 2018, 96.0, 73),
#  ('Seychelles', 2018, 96.0, 74),
#  ('Tunisia', 2018, 95.67, 75),
#  ('Iraq', 2018, 95.67, 76),
#  ('Malaysia', 2018, 95.33, 77),
#  ('Kazakhstan', 2018, 95.0, 78),
#  ('Dominican Republic', 2018, 95.0, 79),
#  ('Saint Vincent and the Grenadines', 2018, 95.0, 80),
#  ('Sri Lanka', 2018, 94.33, 81),
#  ('Honduras', 2018, 94.33, 82),
#  ('Azerbaijan', 2018, 94.33, 83),
#  ('Turks and Caicos Islands', 2018, 94.0, 84),
#  ('Colombia', 2018, 94.0, 85),
#  ('French Guiana', 2018, 94.0, 86),
#  ('Venezuela (Bolivarian Republic of)', 2018, 94.0, 87),
#  ('Syrian Arab Republic', 2018, 93.67, 88),
#  ('Fiji', 2018, 93.67, 89),
#  ("Democratic People's Republic of Korea", 2018, 93.33, 90),
#  ('Philippines', 2018, 93.33, 91),
#  ('Ecuador', 2018, 93.33, 92),
#  ('Guatemala', 2018, 93.0, 93),
#  ('Algeria', 2018, 93.0, 94),
#  ('Vanuatu', 2018, 93.0, 95),
#  ('China', 2018, 92.67, 96),
#  ('Panama', 2018, 92.33, 97),
#  ('Lebanon', 2018, 92.0, 98),
#  ('Samoa', 2018, 92.0, 99),
#  ('Kyrgyzstan', 2018, 91.33, 100),
#  ('South Africa', 2018, 91.33, 101),
#  ('Saint Pierre and Miquelon', 2018, 91.0, 102),
#  ('Falkland Islands (Malvinas)', 2018, 91.0, 103),
#  ('Indonesia', 2018, 90.67, 104),
#  ('India', 2018, 90.33, 105),
#  ('Pakistan', 2018, 90.33, 106),
#  ('Jamaica', 2018, 90.33, 107),
#  ('Marshall Islands', 2018, 90.0, 108),
#  ('Bolivia (Plurinational State of)', 2018, 89.67, 109),
#  ('Nepal', 2018, 89.33, 110),
#  ('Peru', 2018, 88.67, 111),
#  ('Botswana', 2018, 88.33, 112),
#  ('Micronesia (Federated States of)', 2018, 88.0, 113),
#  ('Oman', 2018, 87.0, 114),
#  ('Cabo Verde', 2018, 86.0, 115),
#  ('Morocco', 2018, 85.67, 116),
#  ("Lao People's Democratic Republic", 2018, 85.0, 117),
#  ('Timor-Leste', 2018, 84.33, 118),
#  ('Namibia', 2018, 83.67, 119),
#  ('Tajikistan', 2018, 83.33, 120),
#  ('Ghana', 2018, 82.67, 121),
#  ('Senegal', 2018, 82.67, 122),
#  ('Myanmar', 2018, 82.33, 123),
#  ('Comoros', 2018, 81.67, 124),
#  ('Mali', 2018, 80.67, 125),
#  ('Nicaragua', 2018, 79.33, 126),
#  ('Mongolia', 2018, 79.0, 127),
#  ('Gambia', 2018, 78.67, 128),
#  ('Sao Tome and Principe', 2018, 77.0, 129),
#  ('Lesotho', 2018, 76.0, 130),
#  ('Eswatini', 2018, 75.67, 131),
#  ('Afghanistan', 2018, 75.33, 132),
#  ('Kiribati', 2018, 75.33, 133),
#  ('Cambodia', 2018, 74.67, 134),
#  ('Liberia', 2018, 74.0, 135),
#  ('Nigeria', 2018, 74.0, 136),
#  ('Malawi', 2018, 73.33, 137),
#  ('Gabon', 2018, 73.0, 138),
#  ('Solomon Islands', 2018, 72.33, 139),
#  ("Côte d'Ivoire", 2018, 71.0, 140),
#  ('Mauritania', 2018, 70.0, 141),
#  ('Burundi', 2018, 69.33, 142),
#  ('Djibouti', 2018, 69.33, 143),
#  ('Togo', 2018, 69.33, 144),
#  ('Zimbabwe', 2018, 68.67, 145),
#  ('Congo', 2018, 68.67, 146),
#  ('Guinea', 2018, 67.0, 147),
#  ('Kenya', 2018, 65.67, 148),
#  ('Rwanda', 2018, 65.67, 149),
#  ('Benin', 2018, 65.67, 150),
#  ('Zambia', 2018, 65.33, 151),
#  ('Haiti', 2018, 64.67, 152),
#  ('United Republic of Tanzania', 2018, 63.33, 153),
#  ('Cameroon', 2018, 63.33, 154),
#  ('Sierra Leone', 2018, 62.67, 155),
#  ('Sudan', 2018, 62.33, 156),
#  ('Mozambique', 2018, 62.33, 157),
#  ('Yemen', 2018, 61.33, 158),
#  ('Guinea-Bissau', 2018, 60.0, 159),
#  ('Uganda', 2018, 58.67, 160),
#  ('Niger', 2018, 57.0, 161),
#  ('Papua New Guinea', 2018, 55.67, 162),
#  ('Ethiopia', 2018, 55.67, 163),
#  ('Madagascar', 2018, 55.33, 164),
#  ('Somalia', 2018, 54.67, 165),
#  ('Burkina Faso', 2018, 54.33, 166),
#  ('Angola', 2018, 52.33, 167),
#  ('Chad', 2018, 52.0, 168),
#  ('South Sudan', 2018, 47.67, 169),
#  ('Democratic Republic of the Congo', 2018, 46.67, 170),
#  ('Central African Republic', 2018, 40.67, 171),
#  ('Turkmenistan', 2019, 100.0, 1),
#  ('Republic of Korea', 2019, 100.0, 2),
#  ('Brunei Darussalam', 2019, 100.0, 3),
#  ('Singapore', 2019, 100.0, 4),
#  ('Thailand', 2019, 100.0, 5),
#  ('Bermuda', 2019, 100.0, 6),
#  ('Greenland', 2019, 100.0, 7),
#  ('British Virgin Islands', 2019, 100.0, 8),
#  ('Guadeloupe', 2019, 100.0, 9),
#  ('Martinique', 2019, 100.0, 10),
#  ('Puerto Rico', 2019, 100.0, 11),
#  ('Saint Barthélemy', 2019, 100.0, 12),
#  ('Saint Martin (French Part)', 2019, 100.0, 13),
#  ('Costa Rica', 2019, 100.0, 14),
#  ('Argentina', 2019, 100.0, 15),
#  ('Chile', 2019, 100.0, 16),
#  ('Libya', 2019, 100.0, 17),
#  ('Armenia', 2019, 100.0, 18),
#  ('Bahrain', 2019, 100.0, 19),
#  ('Cyprus', 2019, 100.0, 20),
#  ('Israel', 2019, 100.0, 21),
#  ('Kuwait', 2019, 100.0, 22),
#  ('Qatar', 2019, 100.0, 23),
#  ('Saudi Arabia', 2019, 100.0, 24),
#  ('United Arab Emirates', 2019, 100.0, 25),
#  ('Australia', 2019, 100.0, 26),
#  ('New Zealand', 2019, 100.0, 27),
#  ('Guam', 2019, 100.0, 28),
#  ('Nauru', 2019, 100.0, 29),
#  ('Northern Mariana Islands', 2019, 100.0, 30),
#  ('Palau', 2019, 100.0, 31),
#  ('American Samoa', 2019, 100.0, 32),
#  ('Cook Islands', 2019, 100.0, 33),
#  ('French Polynesia', 2019, 100.0, 34),
#  ('Tokelau', 2019, 100.0, 35),
#  ('Tuvalu', 2019, 100.0, 36),
#  ('Mauritius', 2019, 100.0, 37),
#  ('Réunion', 2019, 100.0, 38),
#  ('Maldives', 2019, 99.67, 39),
#  ('United States of America', 2019, 99.67, 40),
#  ('Paraguay', 2019, 99.67, 41),
#  ('Egypt', 2019, 99.33, 42),
#  ('Japan', 2019, 99.0, 43),
#  ('Canada', 2019, 99.0, 44),
#  ('Bahamas', 2019, 99.0, 45),
#  ('Barbados', 2019, 99.0, 46),
#  ('Trinidad and Tobago', 2019, 99.0, 47),
#  ('United States Virgin Islands', 2019, 99.0, 48),
#  ('New Caledonia', 2019, 99.0, 49),
#  ('Wallis and Futuna Islands', 2019, 99.0, 50),
#  ('Saint Helena', 2019, 99.0, 51),
#  ('Mexico', 2019, 98.67, 52),
#  ('Tonga', 2019, 98.67, 53),
#  ('Belize', 2019, 98.33, 54),
#  ('Jordan', 2019, 98.33, 55),
#  ('Uzbekistan', 2019, 98.0, 56),
#  ('Montserrat', 2019, 98.0, 57),
#  ('Uruguay', 2019, 98.0, 58),
#  ('Bangladesh', 2019, 97.67, 59),
#  ('State of Palestine', 2019, 97.67, 60),
#  ('Bhutan', 2019, 97.33, 61),
#  ('Brazil', 2019, 97.33, 62),
#  ('Suriname', 2019, 97.33, 63),
#  ('Saint Lucia', 2019, 97.0, 64),
#  ('El Salvador', 2019, 97.0, 65),
#  ('Iraq', 2019, 97.0, 66),
#  ('Niue', 2019, 97.0, 67),
#  ('Seychelles', 2019, 97.0, 68),
#  ('Viet Nam', 2019, 96.67, 69),
#  ('Guyana', 2019, 96.67, 70),
#  ('Georgia', 2019, 96.67, 71),
#  ('Türkiye', 2019, 96.67, 72),
#  ('Iran (Islamic Republic of)', 2019, 96.33, 73),
#  ('Cuba', 2019, 96.33, 74),
#  ('Tunisia', 2019, 96.0, 75),
#  ('Mayotte', 2019, 96.0, 76),
#  ('Malaysia', 2019, 95.33, 77),
#  ('Kazakhstan', 2019, 95.0, 78),
#  ('Dominican Republic', 2019, 95.0, 79),
#  ('Azerbaijan', 2019, 95.0, 80),
#  ('Honduras', 2019, 94.67, 81),
#  ('Sri Lanka', 2019, 94.33, 82),
#  ('Colombia', 2019, 94.33, 83),
#  ('Guatemala', 2019, 94.0, 84),
#  ('French Guiana', 2019, 94.0, 85),
#  ('Venezuela (Bolivarian Republic of)', 2019, 94.0, 86),
#  ('Philippines', 2019, 93.67, 87),
#  ('Ecuador', 2019, 93.67, 88),
#  ('Syrian Arab Republic', 2019, 93.67, 89),
#  ('Fiji', 2019, 93.67, 90),
#  ('China', 2019, 93.33, 91),
#  ("Democratic People's Republic of Korea", 2019, 93.33, 92),
#  ('Algeria', 2019, 93.33, 93),
#  ('Lebanon', 2019, 93.0, 94),
#  ('Vanuatu', 2019, 93.0, 95),
#  ('Panama', 2019, 92.67, 96),
#  ('Samoa', 2019, 92.0, 97),
#  ('Kyrgyzstan', 2019, 91.67, 98),
#  ('South Africa', 2019, 91.67, 99),
#  ('Indonesia', 2019, 91.33, 100),
#  ('Saint Pierre and Miquelon', 2019, 91.0, 101),
#  ('Falkland Islands (Malvinas)', 2019, 91.0, 102),
#  ('India', 2019, 90.67, 103),
#  ('Pakistan', 2019, 90.33, 104),
#  ('Jamaica', 2019, 90.33, 105),
#  ('Bolivia (Plurinational State of)', 2019, 90.33, 106),
#  ('Nepal', 2019, 90.0, 107),
#  ('Marshall Islands', 2019, 90.0, 108),
#  ('Botswana', 2019, 89.67, 109),
#  ('Peru', 2019, 89.33, 110),
#  ('Micronesia (Federated States of)', 2019, 88.0, 111),
#  ('Oman', 2019, 87.67, 112),
#  ('Morocco', 2019, 87.33, 113),
#  ("Lao People's Democratic Republic", 2019, 86.67, 114),
#  ('Cabo Verde', 2019, 86.67, 115),
#  ('Timor-Leste', 2019, 86.0, 116),
#  ('Tajikistan', 2019, 85.0, 117),
#  ('Myanmar', 2019, 84.0, 118),
#  ('Senegal', 2019, 84.0, 119),
#  ('Namibia', 2019, 83.67, 120),
#  ('Ghana', 2019, 83.67, 121),
#  ('Mali', 2019, 82.0, 122),
#  ('Comoros', 2019, 81.67, 123),
#  ('Mongolia', 2019, 80.0, 124),
#  ('Nicaragua', 2019, 79.33, 125),
#  ('Gambia', 2019, 79.33, 126),
#  ('Afghanistan', 2019, 78.0, 127),
#  ('Sao Tome and Principe', 2019, 77.33, 128),
#  ('Eswatini', 2019, 76.67, 129),
#  ('Kiribati', 2019, 76.0, 130),
#  ('Lesotho', 2019, 76.0, 131),
#  ('Nigeria', 2019, 75.67, 132),
#  ('Cambodia', 2019, 75.33, 133),
#  ('Liberia', 2019, 75.0, 134),
#  ('Malawi', 2019, 73.67, 135),
#  ('Gabon', 2019, 73.33, 136),
#  ('Solomon Islands', 2019, 72.33, 137),
#  ("Côte d'Ivoire", 2019, 70.67, 138),
#  ('Burundi', 2019, 70.33, 139),
#  ('Togo', 2019, 70.33, 140),
#  ('Mauritania', 2019, 70.0, 141),
#  ('Djibouti', 2019, 69.0, 142),
#  ('Congo', 2019, 69.0, 143),
#  ('Zimbabwe', 2019, 68.33, 144),
#  ('Guinea', 2019, 67.0, 145),
#  ('Kenya', 2019, 66.33, 146),
#  ('Rwanda', 2019, 66.33, 147),
#  ('Zambia', 2019, 66.33, 148),
#  ('Benin', 2019, 65.33, 149),
#  ('Haiti', 2019, 64.67, 150),
#  ('United Republic of Tanzania', 2019, 64.67, 151),
#  ('Mozambique', 2019, 64.33, 152),
#  ('Sierra Leone', 2019, 64.0, 153),
#  ('Cameroon', 2019, 63.33, 154),
#  ('Sudan', 2019, 62.33, 155),
#  ('Yemen', 2019, 62.33, 156),
#  ('Guinea-Bissau', 2019, 60.0, 157),
#  ('Uganda', 2019, 59.33, 158),
#  ('Niger', 2019, 57.33, 159),
#  ('Ethiopia', 2019, 57.0, 160),
#  ('Papua New Guinea', 2019, 56.33, 161),
#  ('Somalia', 2019, 56.33, 162),
#  ('Madagascar', 2019, 56.0, 163),
#  ('Burkina Faso', 2019, 54.0, 164),
#  ('Angola', 2019, 52.33, 165),
#  ('Chad', 2019, 52.33, 166),
#  ('South Sudan', 2019, 48.33, 167),
#  ('Democratic Republic of the Congo', 2019, 47.0, 168),
#  ('Central African Republic', 2019, 39.33, 169),
#  ('Turkmenistan', 2020, 100.0, 1),
#  ('Republic of Korea', 2020, 100.0, 2),
#  ('Brunei Darussalam', 2020, 100.0, 3),
#  ('Singapore', 2020, 100.0, 4),
#  ('Thailand', 2020, 100.0, 5),
#  ('Bermuda', 2020, 100.0, 6),
#  ('Greenland', 2020, 100.0, 7),
#  ('United States of America', 2020, 100.0, 8),
#  ('British Virgin Islands', 2020, 100.0, 9),
#  ('Guadeloupe', 2020, 100.0, 10),
#  ('Martinique', 2020, 100.0, 11),
#  ('Puerto Rico', 2020, 100.0, 12),
#  ('Saint Barthélemy', 2020, 100.0, 13),
#  ('Saint Martin (French Part)', 2020, 100.0, 14),
#  ('Costa Rica', 2020, 100.0, 15),
#  ('Argentina', 2020, 100.0, 16),
#  ('Chile', 2020, 100.0, 17),
#  ('Libya', 2020, 100.0, 18),
#  ('Armenia', 2020, 100.0, 19),
#  ('Bahrain', 2020, 100.0, 20),
#  ('Cyprus', 2020, 100.0, 21),
#  ('Israel', 2020, 100.0, 22),
#  ('Kuwait', 2020, 100.0, 23),
#  ('Qatar', 2020, 100.0, 24),
#  ('Saudi Arabia', 2020, 100.0, 25),
#  ('United Arab Emirates', 2020, 100.0, 26),
#  ('Australia', 2020, 100.0, 27),
#  ('New Zealand', 2020, 100.0, 28),
#  ('Guam', 2020, 100.0, 29),
#  ('Nauru', 2020, 100.0, 30),
#  ('Northern Mariana Islands', 2020, 100.0, 31),
#  ('Palau', 2020, 100.0, 32),
#  ('American Samoa', 2020, 100.0, 33),
#  ('Cook Islands', 2020, 100.0, 34),
#  ('French Polynesia', 2020, 100.0, 35),
#  ('Tokelau', 2020, 100.0, 36),
#  ('Tuvalu', 2020, 100.0, 37),
#  ('Mauritius', 2020, 100.0, 38),
#  ('Réunion', 2020, 100.0, 39),
#  ('Maldives', 2020, 99.67, 40),
#  ('Paraguay', 2020, 99.67, 41),
#  ('Mexico', 2020, 99.33, 42),
#  ('Egypt', 2020, 99.33, 43),
#  ('Japan', 2020, 99.0, 44),
#  ('Canada', 2020, 99.0, 45),
#  ('Barbados', 2020, 99.0, 46),
#  ('Trinidad and Tobago', 2020, 99.0, 47),
#  ('United States Virgin Islands', 2020, 99.0, 48),
#  ('New Caledonia', 2020, 99.0, 49),
#  ('Tonga', 2020, 99.0, 50),
#  ('Wallis and Futuna Islands', 2020, 99.0, 51),
#  ('Saint Helena', 2020, 99.0, 52),
#  ('Belize', 2020, 98.33, 53),
#  ('Brazil', 2020, 98.33, 54),
#  ('Jordan', 2020, 98.33, 55),
#  ('State of Palestine', 2020, 98.33, 56),
#  ('Uzbekistan', 2020, 98.0, 57),
#  ('Montserrat', 2020, 98.0, 58),
#  ('Suriname', 2020, 98.0, 59),
#  ('Uruguay', 2020, 98.0, 60),
#  ('Bangladesh', 2020, 97.67, 61),
#  ('Iraq', 2020, 97.67, 62),
#  ('Bhutan', 2020, 97.33, 63),
#  ('Viet Nam', 2020, 97.33, 64),
#  ('Saint Lucia', 2020, 97.0, 65),
#  ('El Salvador', 2020, 97.0, 66),
#  ('Tunisia', 2020, 97.0, 67),
#  ('Niue', 2020, 97.0, 68),
#  ('Iran (Islamic Republic of)', 2020, 96.67, 69),
#  ('Guyana', 2020, 96.67, 70),
#  ('Georgia', 2020, 96.67, 71),
#  ('Türkiye', 2020, 96.67, 72),
#  ('Cuba', 2020, 96.33, 73),
#  ('Mayotte', 2020, 96.0, 74),
#  ('Azerbaijan', 2020, 95.67, 75),
#  ('Malaysia', 2020, 95.33, 76),
#  ('Honduras', 2020, 95.33, 77),
#  ('Kazakhstan', 2020, 95.0, 78),
#  ('Dominican Republic', 2020, 95.0, 79),
#  ('Colombia', 2020, 94.67, 80),
#  ('Sri Lanka', 2020, 94.33, 81),
#  ('Philippines', 2020, 94.0, 82),
#  ('Guatemala', 2020, 94.0, 83),
#  ('Ecuador', 2020, 94.0, 84),
#  ('French Guiana', 2020, 94.0, 85),
#  ('Venezuela (Bolivarian Republic of)', 2020, 94.0, 86),
#  ('China', 2020, 93.67, 87),
#  ('Syrian Arab Republic', 2020, 93.67, 88),
#  ('Fiji', 2020, 93.67, 89),
#  ("Democratic People's Republic of Korea", 2020, 93.33, 90),
#  ('Algeria', 2020, 93.33, 91),
#  ('Lebanon', 2020, 93.0, 92),
#  ('Vanuatu', 2020, 93.0, 93),
#  ('Kyrgyzstan', 2020, 92.67, 94),
#  ('Panama', 2020, 92.67, 95),
#  ('Indonesia', 2020, 92.0, 96),
#  ('Samoa', 2020, 92.0, 97),
#  ('South Africa', 2020, 92.0, 98),
#  ('India', 2020, 91.0, 99),
#  ('Saint Pierre and Miquelon', 2020, 91.0, 100),
#  ('Falkland Islands (Malvinas)', 2020, 91.0, 101),
#  ('Pakistan', 2020, 90.67, 102),
#  ('Bolivia (Plurinational State of)', 2020, 90.67, 103),
#  ('Jamaica', 2020, 90.33, 104),
#  ('Peru', 2020, 90.33, 105),
#  ('Nepal', 2020, 90.0, 106),
#  ('Marshall Islands', 2020, 90.0, 107),
#  ('Botswana', 2020, 89.67, 108),
#  ('Morocco', 2020, 88.33, 109),
#  ('Oman', 2020, 87.67, 110),
#  ('Cabo Verde', 2020, 87.33, 111),
#  ('Timor-Leste', 2020, 87.0, 112),
#  ("Lao People's Democratic Republic", 2020, 86.67, 113),
#  ('Myanmar', 2020, 85.67, 114),
#  ('Tajikistan', 2020, 85.0, 115),
#  ('Senegal', 2020, 85.0, 116),
#  ('Ghana', 2020, 84.67, 117),
#  ...]

# %% [markdown]
# ### 2. Assess the rankings for countries with the same water level access in a given year.
#
# We expect countries with the same water level access in a given year to have the same rank since they are exactly the same value. Let us assess whether this is the case by filtering our results such that only records with 100% water level access are retrieved.

# %%
# %%sql
# SELECT
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services,
#     ROW_NUMBER()OVER(PARTITION BY Time_period
#         ORDER BY Pct_managed_drinking_water_services DESC) AS Rank_water_services
# FROM
#     united_nations.Access_to_basic_services
# WHERE Pct_managed_drinking_water_services=100;
# Out:
#  * mysql+pymysql://cybergod:***@localhost:3306/united_nations
# 208 rows affected.
# [('Singapore', 2015, 100.0, 1),
#  ('Bermuda', 2015, 100.0, 2),
#  ('Greenland', 2015, 100.0, 3),
#  ('British Virgin Islands', 2015, 100.0, 4),
#  ('Guadeloupe', 2015, 100.0, 5),
#  ('Martinique', 2015, 100.0, 6),
#  ('Saint Barthélemy', 2015, 100.0, 7),
#  ('Saint Martin (French Part)', 2015, 100.0, 8),
#  ('Bahrain', 2015, 100.0, 9),
#  ('Cyprus', 2015, 100.0, 10),
#  ('Israel', 2015, 100.0, 11),
#  ('Kuwait', 2015, 100.0, 12),
#  ('Qatar', 2015, 100.0, 13),
#  ('Saudi Arabia', 2015, 100.0, 14),
#  ('United Arab Emirates', 2015, 100.0, 15),
#  ('Australia', 2015, 100.0, 16),
#  ('New Zealand', 2015, 100.0, 17),
#  ('Guam', 2015, 100.0, 18),
#  ('Nauru', 2015, 100.0, 19),
#  ('Northern Mariana Islands', 2015, 100.0, 20),
#  ('Palau', 2015, 100.0, 21),
#  ('American Samoa', 2015, 100.0, 22),
#  ('Cook Islands', 2015, 100.0, 23),
#  ('French Polynesia', 2015, 100.0, 24),
#  ('Tuvalu', 2015, 100.0, 25),
#  ('Mauritius', 2015, 100.0, 26),
#  ('Réunion', 2015, 100.0, 27),
#  ('Republic of Korea', 2016, 100.0, 1),
#  ('Brunei Darussalam', 2016, 100.0, 2),
#  ('Singapore', 2016, 100.0, 3),
#  ('Bermuda', 2016, 100.0, 4),
#  ('Greenland', 2016, 100.0, 5),
#  ('British Virgin Islands', 2016, 100.0, 6),
#  ('Guadeloupe', 2016, 100.0, 7),
#  ('Martinique', 2016, 100.0, 8),
#  ('Puerto Rico', 2016, 100.0, 9),
#  ('Saint Barthélemy', 2016, 100.0, 10),
#  ('Saint Martin (French Part)', 2016, 100.0, 11),
#  ('Bahrain', 2016, 100.0, 12),
#  ('Cyprus', 2016, 100.0, 13),
#  ('Israel', 2016, 100.0, 14),
#  ('Kuwait', 2016, 100.0, 15),
#  ('Qatar', 2016, 100.0, 16),
#  ('Saudi Arabia', 2016, 100.0, 17),
#  ('United Arab Emirates', 2016, 100.0, 18),
#  ('Australia', 2016, 100.0, 19),
#  ('New Zealand', 2016, 100.0, 20),
#  ('Guam', 2016, 100.0, 21),
#  ('Nauru', 2016, 100.0, 22),
#  ('Northern Mariana Islands', 2016, 100.0, 23),
#  ('Palau', 2016, 100.0, 24),
#  ('American Samoa', 2016, 100.0, 25),
#  ('Cook Islands', 2016, 100.0, 26),
#  ('French Polynesia', 2016, 100.0, 27),
#  ('Tokelau', 2016, 100.0, 28),
#  ('Tuvalu', 2016, 100.0, 29),
#  ('Mauritius', 2016, 100.0, 30),
#  ('Réunion', 2016, 100.0, 31),
#  ('Republic of Korea', 2017, 100.0, 1),
#  ('Brunei Darussalam', 2017, 100.0, 2),
#  ('Singapore', 2017, 100.0, 3),
#  ('Thailand', 2017, 100.0, 4),
#  ('Bermuda', 2017, 100.0, 5),
#  ('Greenland', 2017, 100.0, 6),
#  ('British Virgin Islands', 2017, 100.0, 7),
#  ('Guadeloupe', 2017, 100.0, 8),
#  ('Martinique', 2017, 100.0, 9),
#  ('Puerto Rico', 2017, 100.0, 10),
#  ('Saint Barthélemy', 2017, 100.0, 11),
#  ('Saint Martin (French Part)', 2017, 100.0, 12),
#  ('Costa Rica', 2017, 100.0, 13),
#  ('Argentina', 2017, 100.0, 14),
#  ('Chile', 2017, 100.0, 15),
#  ('Armenia', 2017, 100.0, 16),
#  ('Bahrain', 2017, 100.0, 17),
#  ('Cyprus', 2017, 100.0, 18),
#  ('Israel', 2017, 100.0, 19),
#  ('Kuwait', 2017, 100.0, 20),
#  ('Qatar', 2017, 100.0, 21),
#  ('Saudi Arabia', 2017, 100.0, 22),
#  ('United Arab Emirates', 2017, 100.0, 23),
#  ('Australia', 2017, 100.0, 24),
#  ('New Zealand', 2017, 100.0, 25),
#  ('Guam', 2017, 100.0, 26),
#  ('Nauru', 2017, 100.0, 27),
#  ('Northern Mariana Islands', 2017, 100.0, 28),
#  ('Palau', 2017, 100.0, 29),
#  ('American Samoa', 2017, 100.0, 30),
#  ('Cook Islands', 2017, 100.0, 31),
#  ('French Polynesia', 2017, 100.0, 32),
#  ('Tokelau', 2017, 100.0, 33),
#  ('Tuvalu', 2017, 100.0, 34),
#  ('Mauritius', 2017, 100.0, 35),
#  ('Réunion', 2017, 100.0, 36),
#  ('Republic of Korea', 2018, 100.0, 1),
#  ('Brunei Darussalam', 2018, 100.0, 2),
#  ('Singapore', 2018, 100.0, 3),
#  ('Thailand', 2018, 100.0, 4),
#  ('Bermuda', 2018, 100.0, 5),
#  ('Greenland', 2018, 100.0, 6),
#  ('British Virgin Islands', 2018, 100.0, 7),
#  ('Guadeloupe', 2018, 100.0, 8),
#  ('Martinique', 2018, 100.0, 9),
#  ('Puerto Rico', 2018, 100.0, 10),
#  ('Saint Barthélemy', 2018, 100.0, 11),
#  ('Saint Martin (French Part)', 2018, 100.0, 12),
#  ('Costa Rica', 2018, 100.0, 13),
#  ('Argentina', 2018, 100.0, 14),
#  ('Chile', 2018, 100.0, 15),
#  ('Libya', 2018, 100.0, 16),
#  ('Armenia', 2018, 100.0, 17),
#  ('Bahrain', 2018, 100.0, 18),
#  ('Cyprus', 2018, 100.0, 19),
#  ('Israel', 2018, 100.0, 20),
#  ('Kuwait', 2018, 100.0, 21),
#  ('Qatar', 2018, 100.0, 22),
#  ('Saudi Arabia', 2018, 100.0, 23),
#  ('United Arab Emirates', 2018, 100.0, 24),
#  ('Australia', 2018, 100.0, 25),
#  ('New Zealand', 2018, 100.0, 26),
#  ('Guam', 2018, 100.0, 27),
#  ('Nauru', 2018, 100.0, 28),
#  ('Northern Mariana Islands', 2018, 100.0, 29),
#  ('Palau', 2018, 100.0, 30),
#  ('American Samoa', 2018, 100.0, 31),
#  ('Cook Islands', 2018, 100.0, 32),
#  ('French Polynesia', 2018, 100.0, 33),
#  ('Tokelau', 2018, 100.0, 34),
#  ('Tuvalu', 2018, 100.0, 35),
#  ('Mauritius', 2018, 100.0, 36),
#  ('Réunion', 2018, 100.0, 37),
#  ('Turkmenistan', 2019, 100.0, 1),
#  ('Republic of Korea', 2019, 100.0, 2),
#  ('Brunei Darussalam', 2019, 100.0, 3),
#  ('Singapore', 2019, 100.0, 4),
#  ('Thailand', 2019, 100.0, 5),
#  ('Bermuda', 2019, 100.0, 6),
#  ('Greenland', 2019, 100.0, 7),
#  ('British Virgin Islands', 2019, 100.0, 8),
#  ('Guadeloupe', 2019, 100.0, 9),
#  ('Martinique', 2019, 100.0, 10),
#  ('Puerto Rico', 2019, 100.0, 11),
#  ('Saint Barthélemy', 2019, 100.0, 12),
#  ('Saint Martin (French Part)', 2019, 100.0, 13),
#  ('Costa Rica', 2019, 100.0, 14),
#  ('Argentina', 2019, 100.0, 15),
#  ('Chile', 2019, 100.0, 16),
#  ('Libya', 2019, 100.0, 17),
#  ('Armenia', 2019, 100.0, 18),
#  ('Bahrain', 2019, 100.0, 19),
#  ('Cyprus', 2019, 100.0, 20),
#  ('Israel', 2019, 100.0, 21),
#  ('Kuwait', 2019, 100.0, 22),
#  ('Qatar', 2019, 100.0, 23),
#  ('Saudi Arabia', 2019, 100.0, 24),
#  ('United Arab Emirates', 2019, 100.0, 25),
#  ('Australia', 2019, 100.0, 26),
#  ('New Zealand', 2019, 100.0, 27),
#  ('Guam', 2019, 100.0, 28),
#  ('Nauru', 2019, 100.0, 29),
#  ('Northern Mariana Islands', 2019, 100.0, 30),
#  ('Palau', 2019, 100.0, 31),
#  ('American Samoa', 2019, 100.0, 32),
#  ('Cook Islands', 2019, 100.0, 33),
#  ('French Polynesia', 2019, 100.0, 34),
#  ('Tokelau', 2019, 100.0, 35),
#  ('Tuvalu', 2019, 100.0, 36),
#  ('Mauritius', 2019, 100.0, 37),
#  ('Réunion', 2019, 100.0, 38),
#  ('Turkmenistan', 2020, 100.0, 1),
#  ('Republic of Korea', 2020, 100.0, 2),
#  ('Brunei Darussalam', 2020, 100.0, 3),
#  ('Singapore', 2020, 100.0, 4),
#  ('Thailand', 2020, 100.0, 5),
#  ('Bermuda', 2020, 100.0, 6),
#  ('Greenland', 2020, 100.0, 7),
#  ('United States of America', 2020, 100.0, 8),
#  ('British Virgin Islands', 2020, 100.0, 9),
#  ('Guadeloupe', 2020, 100.0, 10),
#  ('Martinique', 2020, 100.0, 11),
#  ('Puerto Rico', 2020, 100.0, 12),
#  ('Saint Barthélemy', 2020, 100.0, 13),
#  ('Saint Martin (French Part)', 2020, 100.0, 14),
#  ('Costa Rica', 2020, 100.0, 15),
#  ('Argentina', 2020, 100.0, 16),
#  ('Chile', 2020, 100.0, 17),
#  ('Libya', 2020, 100.0, 18),
#  ('Armenia', 2020, 100.0, 19),
#  ('Bahrain', 2020, 100.0, 20),
#  ('Cyprus', 2020, 100.0, 21),
#  ('Israel', 2020, 100.0, 22),
#  ('Kuwait', 2020, 100.0, 23),
#  ('Qatar', 2020, 100.0, 24),
#  ('Saudi Arabia', 2020, 100.0, 25),
#  ('United Arab Emirates', 2020, 100.0, 26),
#  ('Australia', 2020, 100.0, 27),
#  ('New Zealand', 2020, 100.0, 28),
#  ('Guam', 2020, 100.0, 29),
#  ('Nauru', 2020, 100.0, 30),
#  ('Northern Mariana Islands', 2020, 100.0, 31),
#  ('Palau', 2020, 100.0, 32),
#  ('American Samoa', 2020, 100.0, 33),
#  ('Cook Islands', 2020, 100.0, 34),
#  ('French Polynesia', 2020, 100.0, 35),
#  ('Tokelau', 2020, 100.0, 36),
#  ('Tuvalu', 2020, 100.0, 37),
#  ('Mauritius', 2020, 100.0, 38),
#  ('Réunion', 2020, 100.0, 39)]

# %% [markdown]
# ### 3. Apply the `RANK` function instead.
#
# Replace the ranking function used in Exercise 1 with the `RANK()` function, and observe how the results differ.

# %%
# %%sql
# # Add your code here

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### 1. Order countries based on their water access levels per year.
# We apply the `ROW_NUMBER` function as follows:
#
# Firstly, this will partition our dataset by year, that is, the `Time_period` column, then order each partition by water access level, that is, the `Percentage of managed drinking water` column, from the lowest to the highest.
#
# Then, the `ROW_NUMBER` function will assign a rank to each row within a year partition based on the resulting order of rows from the `ORDER BY` clause. The results will then be stored in a new column, `Rank_of_water_services`.

# %%
# %%sql
#
# SELECT
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services,
#     ROW_NUMBER() OVER( PARTITION BY Time_period
#     ORDER BY Pct_managed_drinking_water_services ASC) AS Rank_of_water_services
# FROM
#     united_nations.Access_to_Basic_Services;

# %% [markdown]
# It seems to have worked correctly, seeing that we now have a fourth column which has the ranks for each country based on their water access levels per year, from lowest to highest.

# %% [markdown]
# ### 2.   Assess the rankings for countries with the same water level access in a given year.
#
# Looking at our results, we notice that countries with the same water level access in a given year have different ranks.
#
# To take a closer look, we add a `WHERE` clause that will filter our results such that only records with 100% water level access remain.

# %%
# %%sql
#
# SELECT
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services,
#     ROW_NUMBER() OVER( PARTITION BY Time_period
#     ORDER BY Pct_managed_drinking_water_services ASC) AS Rank_of_water_services
# FROM
#     united_nations.Access_to_Basic_Services
# WHERE
#     Pct_managed_drinking_water_services = 100;

# %% [markdown]
#  Looking at the year 2016, Korea, Brunei, and Singapore, whose access levels were all 100%, have been ranked differently. This is what `ROW_NUMBER()` does, but we want to rank the countries by access level, and countries that have the same access level should share the rank.

# %% [markdown]
# ### 3. Apply the `RANK` function instead.
#
# We can try to correct this by using the `RANK()` function instead, since it assigns the same rank to similar values.
#
# The following query works the same as the previous one with the `ROW_NUMBER()` function, it's just that we now have the `RANK()` function and rows with the same values will receive the same rank, and the next rank(s) are skipped accordingly.

# %%
# %%sql
#
# SELECT
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services,
#     RANK() OVER( PARTITION BY Time_period
#     ORDER BY Pct_managed_drinking_water_services ASC) AS Rank_of_water_services
# FROM
#     united_nations.Access_to_Basic_Services;

# %% [markdown]
# This has worked as expected since we now have the same ranking values for countries with the same water level access in a given year.
#
# We can see that in `2015`, the country with the lowest percentage of managed drinking water services was Afghanistan. Within the same year, we have countries that had the same percentage, such as Nepal and Indonesia, and as a result, they have the same rank, `7`. Due to this, the next rank, `8`, was skipped and the next country, India, given a rank of `9`.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/EAI_Blue_Dark.png"  style="width:200px";/>
# </div>
