# %% [markdown]
# # Using logical and comparison operators
# © ExploreAI Academy

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning Objectives
#
# - Understand the concept of logic and comparison operators in SQL.
# - Learn how to use the WHERE clause to filter data based on specific conditions.
# - Understand the use of IN, BETWEEN, and other SQL operators to streamline queries.

# %% [markdown]
# ## Overview
#
# In this notebook, we will explore the use of logic and comparison operators in SQL to filter and extract specific data from a dataset. These operators are essential tools in SQL that allow us to narrow down our data based on certain conditions.
#
# We will be working with the `united_nations.Access_to_Basic_Services` table, which contains information about different countries, their GDP, access to basic services, and more.

# %% [markdown]
# ### Connecting to our MySQL database
#
# Since we have a MySQL database, we can connect to it using mysql and pymysql.

# %%
# load and activate the SQL extension to allows us to execute SQL in a Jupyter notebook


# %load_ext sql
# %sql mysql+pymysql://cybergod:example-password@localhost:3306/united_nations

# %%
# establish a connection to the local database using the '%sql' magic command,
# replace 'password' with our connection password and `db_name` with our database name


# %sql mysql+pymysql://cybergod:example-password@localhost:3306/united_nations

# %% [markdown]
# ## Exercise
#
# ### Task 1: Basic Filtering with Comparison Operators
#
# You will be working with the `united_nations.Access_to_Basic_Services` table.
# The columns to `SELECT` include
# - `Country_name`
# - `Time_period`
# - `Pct_managed_drinking_water_services`
# - `Pct_managed_sanitation_services`
# - `Est_population_in_millions`
# - and `Est_gdp_in_billions`
#
#
# Use the `WHERE` clause to filter out records of specific countries:
# - `Nigeria`,
# - `Ethiopia`,
# - `Congo`,
# - `Egypt`,
# - `Tanzania`,
# - `Kenya`,
# - and `South Africa`
# - for the time period between `2019` and `2020`.
# Utilize the `OR` operator to include multiple countries in your filter.

# %%
# %%sql
# USE united_nations;
# Out:
#  * mysql+pymysql://cybergod:***@localhost:3306/united_nations
# 0 rows affected.
# []

# %%
# %%sql
# SELECT
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_population_in_millions,
#     Est_gdp_in_billions
# FROM
#     Access_to_basic_services
# WHERE Country_name IN("Nigeria",
# "Ethiopia",
# "Congo",
# "Egypt",
# "Tanzania",
# "Kenya",
# "South Africa")
# AND
#     Time_period BETWEEN 2019 AND 2020;
# Out:
#  * mysql+pymysql://cybergod:***@localhost:3306/united_nations
# 12 rows affected.
# [('Egypt', 2019, 99.33, 97, None, None),
#  ('Egypt', 2020, 99.33, 98, None, None),
#  ('Ethiopia', 2019, 57.0, 12, 114.120594, 95.91),
#  ('Ethiopia', 2020, 58.0, 12, 117.190911, 107.66),
#  ('Kenya', 2019, 66.33, 33, 50.95145, 100.38),
#  ('Kenya', 2020, 67.0, 34, 51.98578, 100.67),
#  ('Congo', 2019, 69.0, 18, None, None),
#  ('Congo', 2020, 69.0, 18, None, None),
#  ('South Africa', 2019, 91.67, 78, 58.087055, 388.53),
#  ('South Africa', 2020, 92.0, 79, 58.801927, 337.62),
#  ('Nigeria', 2019, 75.67, 42, 203.304492, 448.12),
#  ('Nigeria', 2020, 77.33, 43, 208.327405, 432.2)]

# %% [markdown]
# ### Task 2: Streamlining with the IN Operator
#
# Building on the first task, you might have noticed that using multiple `OR` operators can make the query lengthy and a bit complicated. The 'IN' operator offers a more efficient way to achieve the same result.
# The `IN` operator allows you to specify multiple values in a `WHERE` clause, making the query more concise.
# Try to retrieve data for the same list of countries for the same time range, but this time, use the `IN` operator to simplify your query.

# %%
# %%sql
# -- Add your code here

# %% [markdown]
# ### Task 3: Combining Multiple Conditions
#
# The `<=` operator is a comparison operator that checks if the value on the left is less than or equal to the value on the right. In this task, you'll use it to filter countries based on specific service percentages.
# You'll continue working with the `united_nations.Access_to_Basic_Services` table.
# The columns to be selected for this task are
# - `Region`,
# - `Country_name`,
# - `Time_period`,
# - `Pct_managed_drinking_water_services`,
# - `Pct_managed_sanitation_services`,
# - `Est_population_in_millions`, and
# - `Est_gdp_in_billions`.
#
# Your goal is to extract data for the year 2020, focusing on countries where less than or equal to 50% of the population has access to sanitation services. This will help identify countries with critical sanitation needs.
# By using the `<=` operator with the `Pct_managed_sanitation_services` column, you can filter out countries that exceed this threshold, leaving only those with the most pressing sanitation challenges.

# %%
# %%sql
# SELECT
#     Region,
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_population_in_millions,
#     Est_gdp_in_billions
# FROM
#     Access_to_basic_services
# WHERE
#     Time_period=2020
#     AND
#         Pct_managed_sanitation_services<=50;
# Out:
#  * mysql+pymysql://cybergod:***@localhost:3306/united_nations
# 165 rows affected.
# [('Central and Southern Asia', 'Kazakhstan', 2020, 95.0, 98, 18.755666, 171.08),
#  ('Central and Southern Asia', 'Kyrgyzstan', 2020, 92.67, 98, None, None),
#  ('Central and Southern Asia', 'Tajikistan', 2020, 85.0, 96, 9.543207, 8.13),
#  ('Central and Southern Asia', 'Turkmenistan', 2020, 100.0, 99, 6.250438, None),
#  ('Central and Southern Asia', 'Uzbekistan', 2020, 98.0, 100, 34.23205, 59.89),
#  ('Central and Southern Asia', 'Afghanistan', 2020, 80.33, 54, 38.97223, 20.14),
#  ('Central and Southern Asia', 'Bangladesh', 2020, 97.67, 54, 167.420951, 373.9),
#  ('Central and Southern Asia', 'Bhutan', 2020, 97.33, 77, 0.772506, 2.33),
#  ('Central and Southern Asia', 'India', 2020, 91.0, 72, 1396.387127, 2667.69),
#  ('Central and Southern Asia', 'Iran (Islamic Republic of)', 2020, 96.67, 88, None, None),
#  ('Central and Southern Asia', 'Maldives', 2020, 99.67, 99, 0.514438, 3.75),
#  ('Central and Southern Asia', 'Nepal', 2020, 90.0, 77, 29.348627, 33.43),
#  ('Central and Southern Asia', 'Pakistan', 2020, 90.67, 70, 227.196741, 300.43),
#  ('Central and Southern Asia', 'Sri Lanka', 2020, 94.33, 94, 21.919, 85.35),
#  ('Eastern and South-Eastern Asia', 'China', 2020, 93.67, 92, 1411.1, 14687.67),
#  ('Eastern and South-Eastern Asia', "Democratic People's Republic of Korea", 2020, 93.33, 83, None, None),
#  ('Eastern and South-Eastern Asia', 'Japan', 2020, 99.0, 100, 126.261, 5040.11),
#  ('Eastern and South-Eastern Asia', 'Mongolia', 2020, 81.0, 65, 3.294335, 13.31),
#  ('Eastern and South-Eastern Asia', 'Republic of Korea', 2020, 100.0, 100, None, None),
#  ('Eastern and South-Eastern Asia', 'Brunei Darussalam', 2020, 100.0, None, 0.441725, 12.01),
#  ('Eastern and South-Eastern Asia', 'Cambodia', 2020, 75.33, 74, 16.39686, 25.87),
#  ('Eastern and South-Eastern Asia', 'Indonesia', 2020, 92.0, 86, 271.85797, 1058.69),
#  ('Eastern and South-Eastern Asia', "Lao People's Democratic Republic", 2020, 86.67, 82, None, None),
#  ('Eastern and South-Eastern Asia', 'Malaysia', 2020, 95.33, 100, 33.199993, 337.34),
#  ('Eastern and South-Eastern Asia', 'Myanmar', 2020, 85.67, 75, 53.423198, 78.93),
#  ('Eastern and South-Eastern Asia', 'Philippines', 2020, 94.0, 82, 112.190977, 361.75),
#  ('Eastern and South-Eastern Asia', 'Singapore', 2020, 100.0, 100, 5.685807, 345.3),
#  ('Eastern and South-Eastern Asia', 'Thailand', 2020, 100.0, 99, 71.475664, 499.68),
#  ('Eastern and South-Eastern Asia', 'Timor-Leste', 2020, 87.0, 60, 1.299995, 2.16),
#  ('Eastern and South-Eastern Asia', 'Viet Nam', 2020, 97.33, 90, None, None),
#  ('Europe and Northern America', 'Bermuda', 2020, 100.0, 100, 0.063893, 6.89),
#  ('Europe and Northern America', 'Canada', 2020, 99.0, 99, 38.037204, 1645.42),
#  ('Europe and Northern America', 'Greenland', 2020, 100.0, 100, 0.056367, 3.08),
#  ('Europe and Northern America', 'Saint Pierre and Miquelon', 2020, 91.0, 100, None, None),
#  ('Europe and Northern America', 'United States of America', 2020, 100.0, 100, None, None),
#  ('Latin America and the Caribbean', 'Barbados', 2020, 99.0, 98, 0.280693, 4.67),
#  ('Latin America and the Caribbean', 'British Virgin Islands', 2020, 100.0, None, 0.03091, None),
#  ('Latin America and the Caribbean', 'Cuba', 2020, 96.33, 90, 11.300698, 107.35),
#  ('Latin America and the Caribbean', 'Dominican Republic', 2020, 95.0, 84, 10.999664, 78.84),
#  ('Latin America and the Caribbean', 'Guadeloupe', 2020, 100.0, 100, None, None),
#  ('Latin America and the Caribbean', 'Haiti', 2020, 65.0, 36, 11.306801, 14.51),
#  ('Latin America and the Caribbean', 'Jamaica', 2020, 90.33, 87, 2.820436, 13.81),
#  ('Latin America and the Caribbean', 'Martinique', 2020, 100.0, 100, None, None),
#  ('Latin America and the Caribbean', 'Montserrat', 2020, 98.0, 89, None, None),
#  ('Latin America and the Caribbean', 'Puerto Rico', 2020, 100.0, 100, 3.281538, 103.02),
#  ('Latin America and the Caribbean', 'Saint Barthélemy', 2020, 100.0, 100, None, None),
#  ('Latin America and the Caribbean', 'Saint Lucia', 2020, 97.0, 82, None, None),
#  ('Latin America and the Caribbean', 'Saint Martin (French Part)', 2020, 100.0, 100, None, None),
#  ('Latin America and the Caribbean', 'Trinidad and Tobago', 2020, 99.0, 94, 1.518147, 21.06),
#  ('Latin America and the Caribbean', 'United States Virgin Islands', 2020, 99.0, 99, None, None),
#  ('Latin America and the Caribbean', 'Belize', 2020, 98.33, 89, 0.394921, 2.08),
#  ('Latin America and the Caribbean', 'Costa Rica', 2020, 100.0, 98, 5.123105, 62.16),
#  ('Latin America and the Caribbean', 'El Salvador', 2020, 97.0, 80, 6.292731, 24.56),
#  ('Latin America and the Caribbean', 'Guatemala', 2020, 94.0, 68, 16.858333, 77.63),
#  ('Latin America and the Caribbean', 'Honduras', 2020, 95.33, 83, 10.121763, 23.83),
#  ('Latin America and the Caribbean', 'Mexico', 2020, 99.33, 91, 125.998302, 1090.52),
#  ('Latin America and the Caribbean', 'Nicaragua', 2020, 79.33, 72, 6.755895, 12.59),
#  ('Latin America and the Caribbean', 'Panama', 2020, 92.67, 81, 4.294396, 53.98),
#  ('Latin America and the Caribbean', 'Argentina', 2020, 100.0, 99, 45.376763, 385.54),
#  ('Latin America and the Caribbean', 'Bolivia (Plurinational State of)', 2020, 90.67, 62, None, None),
#  ('Latin America and the Caribbean', 'Brazil', 2020, 98.33, 82, 213.196304, 1448.56),
#  ('Latin America and the Caribbean', 'Chile', 2020, 100.0, 100, 19.300315, 252.73),
#  ('Latin America and the Caribbean', 'Colombia', 2020, 94.67, 91, 50.930662, 270.3),
#  ('Latin America and the Caribbean', 'Ecuador', 2020, 94.0, 91, 17.588595, 99.29),
#  ('Latin America and the Caribbean', 'Falkland Islands (Malvinas)', 2020, 91.0, 100, None, None),
#  ('Latin America and the Caribbean', 'French Guiana', 2020, 94.0, 92, None, None),
#  ('Latin America and the Caribbean', 'Guyana', 2020, 96.67, 87, 0.797202, 5.47),
#  ('Latin America and the Caribbean', 'Paraguay', 2020, 99.67, 92, 6.618695, 35.43),
#  ('Latin America and the Caribbean', 'Peru', 2020, 90.33, 74, 33.304756, 201.71),
#  ('Latin America and the Caribbean', 'Suriname', 2020, 98.0, 89, 0.607065, 2.91),
#  ('Latin America and the Caribbean', 'Uruguay', 2020, 98.0, 98, 3.429086, 53.56),
#  ('Latin America and the Caribbean', 'Venezuela (Bolivarian Republic of)', 2020, 94.0, 96, None, None),
#  ('Northern Africa and Western Asia', 'Algeria', 2020, 93.33, 84, 43.451666, 145.01),
#  ('Northern Africa and Western Asia', 'Egypt', 2020, 99.33, 98, None, None),
#  ('Northern Africa and Western Asia', 'Libya', 2020, 100.0, 92, 6.653942, 50.36),
#  ('Northern Africa and Western Asia', 'Morocco', 2020, 88.33, 85, 36.688772, 121.35),
#  ('Northern Africa and Western Asia', 'Sudan', 2020, 62.33, 40, 44.440486, 27.03),
#  ('Northern Africa and Western Asia', 'Tunisia', 2020, 97.0, 97, 12.161723, 42.54),
#  ('Northern Africa and Western Asia', 'Armenia', 2020, 100.0, 92, 2.805608, 12.64),
#  ('Northern Africa and Western Asia', 'Azerbaijan', 2020, 95.67, 96, 10.093121, 42.69),
#  ('Northern Africa and Western Asia', 'Bahrain', 2020, 100.0, 100, 1.477469, 34.72),
#  ('Northern Africa and Western Asia', 'Cyprus', 2020, 100.0, 99, 1.237537, 25.01),
#  ('Northern Africa and Western Asia', 'Georgia', 2020, 96.67, 84, 3.722716, 15.84),
#  ('Northern Africa and Western Asia', 'Iraq', 2020, 97.67, 100, 42.556984, 184.37),
#  ('Northern Africa and Western Asia', 'Israel', 2020, 100.0, 100, 9.2151, 413.27),
#  ('Northern Africa and Western Asia', 'Jordan', 2020, 98.33, 96, 10.928721, 44.18),
#  ('Northern Africa and Western Asia', 'Kuwait', 2020, 100.0, 100, 4.360444, 105.96),
#  ('Northern Africa and Western Asia', 'Lebanon', 2020, 93.0, 99, 5.662923, 31.71),
#  ('Northern Africa and Western Asia', 'Oman', 2020, 87.67, 99, 4.543399, 75.91),
#  ('Northern Africa and Western Asia', 'Qatar', 2020, 100.0, 100, 2.760385, 144.41),
#  ('Northern Africa and Western Asia', 'Saudi Arabia', 2020, 100.0, 100, 35.997107, 703.37),
#  ('Northern Africa and Western Asia', 'State of Palestine', 2020, 98.33, 99, None, None),
#  ('Northern Africa and Western Asia', 'Syrian Arab Republic', 2020, 93.67, 90, 20.772595, 11.08),
#  ('Northern Africa and Western Asia', 'Türkiye', 2020, 96.67, 99, None, None),
#  ('Northern Africa and Western Asia', 'United Arab Emirates', 2020, 100.0, 99, 9.287289, 349.47),
#  ('Northern Africa and Western Asia', 'Yemen', 2020, 63.0, 57, None, None),
#  ('Oceania', 'Australia', 2020, 100.0, 100, 25.655289, 1326.9),
#  ('Oceania', 'New Zealand', 2020, 100.0, 100, 5.0902, 211.73),
#  ('Oceania', 'Fiji', 2020, 93.67, 99, 0.920422, 4.48),
#  ('Oceania', 'New Caledonia', 2020, 99.0, 100, 0.27113, 9.44),
#  ('Oceania', 'Papua New Guinea', 2020, 56.67, 28, 9.74964, 23.85),
#  ('Oceania', 'Solomon Islands', 2020, 72.33, 45, 0.691191, 1.54),
#  ('Oceania', 'Vanuatu', 2020, 93.0, 56, 0.311685, 0.9),
#  ('Oceania', 'Guam', 2020, 100.0, None, 0.169231, 5.89),
#  ('Oceania', 'Kiribati', 2020, 77.0, 45, 0.126463, 0.18),
#  ('Oceania', 'Marshall Islands', 2020, 90.0, 78, 0.043413, 0.24),
#  ('Oceania', 'Nauru', 2020, 100.0, None, 0.012315, 0.11),
#  ('Oceania', 'Northern Mariana Islands', 2020, 100.0, 79, 0.049587, None),
#  ('Oceania', 'Palau', 2020, 100.0, 100, 0.017972, 0.25),
#  ('Oceania', 'American Samoa', 2020, 100.0, 54, 0.046189, 0.72),
#  ('Oceania', 'Cook Islands', 2020, 100.0, 99, None, None),
#  ('Oceania', 'French Polynesia', 2020, 100.0, 97, 0.30192, 5.71),
#  ('Oceania', 'Niue', 2020, 97.0, 96, None, None),
#  ('Oceania', 'Samoa', 2020, 92.0, 96, 0.214929, 0.87),
#  ('Oceania', 'Tokelau', 2020, 100.0, 97, None, None),
#  ('Oceania', 'Tonga', 2020, 99.0, 93, 0.105254, 0.48),
#  ('Oceania', 'Tuvalu', 2020, 100.0, None, 0.011069, 0.06),
#  ('Oceania', 'Wallis and Futuna Islands', 2020, 99.0, 93, None, None),
#  ('Sub-Saharan Africa', 'Burundi', 2020, 70.33, 44, 12.220227, 2.65),
#  ('Sub-Saharan Africa', 'Djibouti', 2020, 69.0, 56, 1.090156, 3.18),
#  ('Sub-Saharan Africa', 'Ethiopia', 2020, 58.0, 12, 117.190911, 107.66),
#  ('Sub-Saharan Africa', 'Kenya', 2020, 67.0, 34, 51.98578, 100.67),
#  ('Sub-Saharan Africa', 'Madagascar', 2020, 56.33, 13, 28.225177, 13.05),
#  ('Sub-Saharan Africa', 'Malawi', 2020, 74.33, 29, 19.377061, 12.18),
#  ('Sub-Saharan Africa', 'Mauritius', 2020, 100.0, 96, 1.26574, 11.4),
#  ('Sub-Saharan Africa', 'Mayotte', 2020, 96.0, 100, None, None),
#  ('Sub-Saharan Africa', 'Mozambique', 2020, 66.67, 40, 31.178239, 14.03),
#  ('Sub-Saharan Africa', 'Rwanda', 2020, 66.33, 64, 13.146362, 10.18),
#  ('Sub-Saharan Africa', 'Réunion', 2020, 100.0, 100, None, None),
#  ('Sub-Saharan Africa', 'Somalia', 2020, 57.33, 40, 16.537016, 6.88),
#  ('Sub-Saharan Africa', 'South Sudan', 2020, 48.33, 22, 10.606227, None),
#  ('Sub-Saharan Africa', 'Uganda', 2020, 61.0, 22, 44.404611, 37.6),
#  ('Sub-Saharan Africa', 'United Republic of Tanzania', 2020, 65.0, 34, None, None),
#  ('Sub-Saharan Africa', 'Zambia', 2020, 66.67, 33, 18.927715, 18.11),
#  ('Sub-Saharan Africa', 'Zimbabwe', 2020, 68.0, 36, 15.669666, 21.51),
#  ('Sub-Saharan Africa', 'Angola', 2020, 52.33, 47, 33.428486, 53.62),
#  ('Sub-Saharan Africa', 'Cameroon', 2020, 64.0, 43, 26.491087, 40.77),
#  ('Sub-Saharan Africa', 'Central African Republic', 2020, 38.33, 15, 5.34302, 2.33),
#  ('Sub-Saharan Africa', 'Chad', 2020, 52.67, 19, 16.644701, 10.72),
#  ('Sub-Saharan Africa', 'Congo', 2020, 69.0, 18, None, None),
#  ('Sub-Saharan Africa', 'Democratic Republic of the Congo', 2020, 47.67, 15, None, None),
#  ('Sub-Saharan Africa', 'Gabon', 2020, 73.33, 47, 2.292573, 15.31),
#  ('Sub-Saharan Africa', 'Sao Tome and Principe', 2020, 77.33, 46, 0.218641, 0.47),
#  ('Sub-Saharan Africa', 'Botswana', 2020, 89.67, 74, 2.546402, 14.93),
#  ('Sub-Saharan Africa', 'Eswatini', 2020, 76.67, 61, 1.180655, 3.98),
#  ('Sub-Saharan Africa', 'Lesotho', 2020, 76.33, 50, 2.2541, 2.23),
#  ('Sub-Saharan Africa', 'Namibia', 2020, 83.67, 35, 2.489098, 10.58),
#  ('Sub-Saharan Africa', 'South Africa', 2020, 92.0, 79, 58.801927, 337.62),
#  ('Sub-Saharan Africa', 'Benin', 2020, 65.33, 17, 12.643123, 15.65),
#  ('Sub-Saharan Africa', 'Burkina Faso', 2020, 53.33, 25, 21.522626, 17.93),
#  ('Sub-Saharan Africa', 'Cabo Verde', 2020, 87.33, 78, 0.58264, 1.7),
#  ('Sub-Saharan Africa', "Côte d'Ivoire", 2020, 70.67, 35, None, None),
#  ('Sub-Saharan Africa', 'Gambia', 2020, 79.33, 44, None, None),
#  ('Sub-Saharan Africa', 'Ghana', 2020, 84.67, 23, 32.180401, 70.04),
#  ('Sub-Saharan Africa', 'Guinea', 2020, 67.33, 32, 13.205153, 14.18),
#  ('Sub-Saharan Africa', 'Guinea-Bissau', 2020, 60.0, 19, 2.015828, 1.43),
#  ('Sub-Saharan Africa', 'Liberia', 2020, 75.0, 18, 5.087584, 3.04),
#  ('Sub-Saharan Africa', 'Mali', 2020, 83.67, 46, 21.22404, 17.47),
#  ('Sub-Saharan Africa', 'Mauritania', 2020, 70.33, 48, 4.498604, 8.41),
#  ('Sub-Saharan Africa', 'Niger', 2020, 57.33, 25, 24.333639, 13.74),
#  ('Sub-Saharan Africa', 'Nigeria', 2020, 77.33, 43, 208.327405, 432.2),
#  ('Sub-Saharan Africa', 'Saint Helena', 2020, 99.0, 100, None, None),
#  ('Sub-Saharan Africa', 'Senegal', 2020, 85.0, 57, 16.43612, 24.49),
#  ('Sub-Saharan Africa', 'Sierra Leone', 2020, 65.0, 17, 8.23397, 4.06),
#  ('Sub-Saharan Africa', 'Togo', 2020, 70.67, 20, 8.44258, 7.57)]

# %% [markdown]
# ## Solutions
#
# ### Task 1: Basic Filtering with Comparison Operators

# %%
# %%sql
# SELECT
# Country_name,
# Time_period,
# Pct_managed_drinking_water_services,
# Pct_managed_sanitation_services,
# Est_population_in_millions,
# Est_gdp_in_billions
# FROM
# united_nations.Access_to_Basic_Services
# WHERE
# (Country_name = 'Nigeria'
# OR Country_name = 'Ethiopia'
# OR Country_name = 'Congo'
# OR Country_name = 'Egypt'
# OR Country_name = 'Tanzania'
# OR Country_name = 'Kenya'
# OR Country_name ='South Africa')
# AND Time_period BETWEEN 2019 AND 2020;

# %% [markdown]
# ### Task 2: Streamlining with the IN Operator

# %%
# %%sql
# SELECT
# Country_name,
# Time_period,
# Pct_managed_drinking_water_services,
# Pct_managed_sanitation_services,
# Est_population_in_millions,
# Est_gdp_in_billions
# FROM
# united_nations.Access_to_Basic_Services
# WHERE
# Country_name IN (
#         'Nigeria',
#         'Ethiopia' ,
#         'Congo',
#         'Egypt',
#         'Tanzania',
#         'Kenya',
#         'South Africa'
#  )
# AND Time_period BETWEEN 2019 AND 2020;

# %% [markdown]
# ### Task 3: Combining Multiple Conditions

# %%
# %%sql
# SELECT
# Region,
# Country_name,
# Time_period,
# Pct_managed_drinking_water_services,
# Pct_managed_sanitation_services,
# Est_population_in_millions,
# Est_gdp_in_billions
# FROM
# united_nations.Access_to_Basic_Services
# WHERE
# Time_period = 2020
# AND Pct_managed_sanitation_services <= 50;

# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/EAI_Blue_Dark.png"  style="width:200px";/>
# </div>
